# %% [markdown]
# Limitations de la plage de dates :
#
# startDateet endDatedoit suivre le format ISO 8601 :
#
# Format de base : "yyyy-MM-dd" (par défaut minuit).
#
# Format complet avec décalage horaire : "yyyy-MM-dd'T'HH:mm:ssXXX" (doit être codé en URL, par exemple, 2023-01-01T00:00:00%2B02:00).
#
# Comportement:
#
# Les deux startDatesont endDateinclus dans la réponse.
#
# Si endDateest omis, la valeur par défaut est la date actuelle ou la plage maximale autorisée après startDate.
#
# Si startDateest omis, la valeur par défaut est la date la plus ancienne autorisée dans la plage de l'ensemble de données.
#
# Si les deux sont omis, l'API définit automatiquement :
#
# endDate = current time
#
# startDate = endDate - max allowed range (day/week/month, depending on the dataset)

# %%
import requests
import pandas as pd
import csv
from datetime import datetime, timedelta
import time

# %% [markdown]
# ## Test initial de l'API

# %% [markdown]
# ### Explication du code
# Objectif : Comprendre la structure des données retournées par l'API Elhub avant d'implémenter la collecte automatisée.
#
# ### Paramètres de test utilisés :
# Dataset : CONSUMPTION_PER_GROUP_MUNICIPALITY_HOUR - Consommation par groupe et municipalité par heure
#
# Date de début : 2023-05-03T20:00:00+02:00 - 3 mai 2023 à 20h00
#
# Date de fin : 2023-05-04T00:00:00+02:00 - 4 mai 2023 à 00h00 (période de 4 heures)
#
# Groupe de consommation : private - Consommation privée
#
# Période choisie : Une courte période (4 heures) pour limiter le volume de données lors de cette exploration initiale.
#
# ### Résultat attendu
# Ce test permet de :
#
# 1.Vérifier la connectivité à l'API
#
# 2.Comprendre le format JSON retourné
#
# 3.Identifier les champs disponibles dans les données
#
# 4.Valider les paramètres de requête
#
# ### Prochaines étapes
# Une fois la structure des données comprise grâce à ce test, l'objectif est d'automatiser la collecte sur des périodes plus longues et de traiter les données de manière systématique.
#
# Note : Ce code est un exemple d'exploration tiré directement du site de l'API Elhub pour des fins de test et de compréhension de la structure des données.

# %% [markdown]
# ### Code d'exploration

# %%
# Define the headers for the request
headers = {}
# Make a request to the Elhub API to get municipalities data
response = requests.get('https://api.elhub.no/energy-data/v0/municipalities?dataset=CONSUMPTION_PER_GROUP_MUNICIPALITY_HOUR&startDate=2023-05-03T20:00:00%2B02:00&endDate=2023-05-04T00:00:00%2B02:00&consumptionGroup=private', headers=headers)
if response.status_code == 200: # Check if the request was successful
    print(response.json())
else:
    print('Error:', response.status_code)
# Out:
# {'meta': {'created': '2025-05-26T13:49:09+02:00', 'lastUpdated': '2025-03-29T01:42:43+01:00'}, 'links': {'self': 'https://api.elhub.no/energy-data/v0/municipalities?consumptionGroup=private&dataset=CONSUMPTION_PER_GROUP_MUNICIPALITY_HOUR&endDate=2023-05-04T00%3A00%3A00%2B02%3A00&startDate=2023-05-03T20%3A00%3A00%2B02%3A00'}, 'data': [{'type': 'municipality', 'id': '*', 'attributes': {'municipalityNumber': '*', 'name': '*', 'nameNo': '*', 'consumptionPerGroupMunicipalityHour': []}}, {'type': 'municipality', 'id': '0000', 'attributes': {'municipalityNumber': '0000', 'name': 'Ukjent tilhørighet', 'nameNo': 'Ukjent tilhørighet', 'consumptionPerGroupMunicipalityHour': [{'startTime': '2023-05-03T20:00:00+02:00', 'endTime': '2023-05-03T21:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 2094.047, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 1363}, {'startTime': '2023-05-03T21:00:00+02:00', 'endTime': '2023-05-03T22:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 2138.683, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 1363}, {'startTime': '2023-05-03T22:00:00+02:00', 'endTime': '2023-05-03T23:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 2191.614, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 1363}, {'startTime': '2023-05-03T23:00:00+02:00', 'endTime': '2023-05-04T00:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 2120.537, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 1363}]}}, {'type': 'municipality', 'id': '0301', 'attributes': {'municipalityNumber': '0301', 'name': 'Oslo', 'nameNo': 'Oslo', 'consumptionPerGroupMunicipalityHour': [{'startTime': '2023-05-03T20:00:00+02:00', 'endTime': '2023-05-03T21:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 486719.5, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 349073}, {'startTime': '2023-05-03T21:00:00+02:00', 'endTime': '2023-05-03T22:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 494802.0, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 349073}, {'startTime': '2023-05-03T22:00:00+02:00', 'endTime': '2023-05-03T23:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 482521.4, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 349073}, {'startTime': '2023-05-03T23:00:00+02:00', 'endTime': '2023-05-04T00:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 438644.28, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 349073}]}}, {'type': 'municipality', 'id': '1101', 'attributes': {'municipalityNumber': '1101', 'name': 'Eigersund', 'nameNo': 'Eigersund', 'consumptionPerGroupMunicipalityHour': [{'startTime': '2023-05-03T20:00:00+02:00', 'endTime': '2023-05-03T21:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 11382.4, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 7912}, {'startTime': '2023-05-03T21:00:00+02:00', 'endTime': '2023-05-03T22:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 11737.927, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 7912}, {'startTime': '2023-05-03T22:00:00+02:00', 'endTime': '2023-05-03T23:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 11809.926, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 7912}, {'startTime': '2023-05-03T23:00:00+02:00', 'endTime': '2023-05-04T00:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 11029.901, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 7912}]}}, {'type': 'municipality', 'id': '1103', 'attributes': {'municipalityNumber': '1103', 'name': 'Stavanger', 'nameNo': 'Stavanger', 'consumptionPerGroupMunicipalityHour': [{'startTime': '2023-05-03T20:00:00+02:00', 'endTime': '2023-05-03T21:00:00+02:00', 'consumptionGroup': 'private', 'quantityKwh': 105387.82, 'lastUpdatedTime': '2025-03-29T01:42:43+01:00', 'meteringPointCount': 69288}, {'s ...

# %%
# Constants
dataset = "CONSUMPTION_PER_GROUP_MUNICIPALITY_HOUR" # Dataset identifier in the API
consumption_groups = ["private", "industry", "business"] # List of consumption groups to retrieve data for
base_url = "https://api.elhub.no/energy-data/v0/municipalities"  # Base URL for the API endpoint

# Start and end dates for data retrieval
start_date = datetime(2021, 1, 1) # Start date for data collection autorised by the API
end_limit = datetime.now() # Current date and time

# Loop over each consumption group to create separate CSV files
for group in consumption_groups:
    file_name = f"municipalities_group_{group}_consumption.csv" # Name of the output CSV file for the current group
    print(f"\nStarting data extraction for consumption group: {group}") # Print the current group being processed
    
    # Ensemble pour collecter automatiquement tous les en-têtes possibles
    all_fieldnames = set()
    all_rows = []  # Stocker toutes les lignes pour les écrire après avoir collecté les en-têtes
    
    current_date = start_date # Initialize current date to start date will be incremented day by day
    
    # Loop day by day until end_limit
    while current_date < end_limit:
        end_date = current_date + timedelta(days=1) # Define the end date for the current day 1 day later because the API requires a range of dates in one request
        
        # Format dates as ISO 8601 (YYYY-MM-DD)
        start_str = current_date.strftime("%Y-%m-%d") # Format start date to string because the API requires date strings 
        end_str = end_date.strftime("%Y-%m-%d")
        
        # Construct API URL with parameters for current group and date range
        url = (
            f"{base_url}?dataset={dataset}"
            f"&startDate={start_str}"
            f"&endDate={end_str}"
            f"&consumptionGroup={group}"
        ) # Construct the full URL for the API request
        print(f"API call: {start_str} → {end_str} for group '{group}'")  # Print the API call being made
        
        try:  # Make the API request in a try-except block to handle potential errors
            response = requests.get(url)   # Send GET request to the API
            if response.status_code == 200:   # Check if the request was successful 200 because it means OK in HTTP status codes
                json_full = response.json()   # Parse the JSON response from the API because the API returns data in JSON format
                data = json_full.get("data", []) # Extract the "data" field from the JSON response, defaulting to an empty list if not present
                
                # Extract relevant fields from the JSON response
                for item in data: # Loop through each item in the data list
                    if not isinstance(item, dict):   # Check if the item is a dictionary 
                        continue
                    
                    # Structure de base de l'item before adding attributes 
                    base_row = {
                        "type": item.get("type"), 
                        "id": item.get("id")
                    }
                    
                    attr = item.get("attributes", {}) # Extract the "attributes" field, defaulting to an empty dictionary if not present
                    
                    # Ajouter automatiquement tous les attributs au niveau municipality 
                    for attr_key, attr_value in attr.items():  # Loop through each attribute in the attributes dictionary
                        if attr_key != "consumptionPerGroupMunicipalityHour":  # Skip the nested consumption data
                            base_row[attr_key] = attr_value 
                    
                    # Loop through the hourly consumption records
                    for record in attr.get("consumptionPerGroupMunicipalityHour", []): 
                        # Créer une ligne complète en combinant les infos de base et les données horaires
                        row = {**base_row}  # Copier les données de base
                        
                        # Ajouter automatiquement toutes les données du record
                        for record_key, record_value in record.items():
                            row[record_key] = record_value   # Add each record key-value pair to the row
                        
                        # Ajouter toutes les clés trouvées à notre ensemble d'en-têtes
                        all_fieldnames.update(row.keys())
                        all_rows.append(row)
                
                if data:
                    print(f"  {len(data)} records processed for date {start_str}") # Print the number of records processed for the current date
                else:
                    print(f"  No data for date {start_str}") # Print if no data was found for the current date
            else:
                print(f"API call failed with status code: {response.status_code}") # Print error if the API call was not successful
                
        except Exception as e:
            print(f"API error: {e}") # Print any exceptions that occur during the API call
        
        # Move to next day
        current_date = end_date # Increment the current date by one day to process the next date
        time.sleep(1)  # Sleep 1 second to avoid rate limiting because the API may have rate limits on requests
    
    # Écrire toutes les données dans le fichier CSV avec les en-têtes détectées automatiquement
    if all_rows: # Check if there are any rows to write
        with open(file_name, mode="w", newline="", encoding="utf-8") as file: # Open the file for writing
            # Trier les en-têtes pour avoir un ordre cohérent
            sorted_fieldnames = sorted(all_fieldnames) 
            writer = csv.DictWriter(file, fieldnames=sorted_fieldnames)
            writer.writeheader() # Write the header row with sorted fieldnames
            writer.writerows(all_rows)
        
        print(f"Data saved to file: {file_name}")
        print(f"Detected fieldnames: {sorted_fieldnames}")
        print(f"Total rows: {len(all_rows)}")
    else:
        print(f"No data found for group: {group}") # Print if no data was found for the current group
# Out:
# Starting data extraction for consumption group: private
# API call: 2025-07-13 → 2025-07-14 for group 'private'
#   361 records processed for date 2025-07-13
# API call: 2025-07-14 → 2025-07-15 for group 'private'
#   361 records processed for date 2025-07-14
# API call: 2025-07-15 → 2025-07-16 for group 'private'
#   361 records processed for date 2025-07-15
# API call: 2025-07-16 → 2025-07-17 for group 'private'
#   361 records processed for date 2025-07-16
# API call: 2025-07-17 → 2025-07-18 for group 'private'
#   361 records processed for date 2025-07-17
# Data saved to file: municipalities_group_private_consumption.csv
# Detected fieldnames: ['consumptionGroup', 'endTime', 'id', 'lastUpdatedTime', 'meteringPointCount', 'municipalityNumber', 'name', 'nameNo', 'quantityKwh', 'startTime', 'type']
# Total rows: 25776
#
# Starting data extraction for consumption group: industry
# API call: 2025-07-13 → 2025-07-14 for group 'industry'
#   361 records processed for date 2025-07-13
# API call: 2025-07-14 → 2025-07-15 for group 'industry'
#   361 records processed for date 2025-07-14
# API call: 2025-07-15 → 2025-07-16 for group 'industry'
#   361 records processed for date 2025-07-15
# API call: 2025-07-16 → 2025-07-17 for group 'industry'
#   361 records processed for date 2025-07-16
# API call: 2025-07-17 → 2025-07-18 for group 'industry'
#   361 records processed for date 2025-07-17
# Data saved to file: municipalities_group_industry_consumption.csv
# Detected fieldnames: ['consumptionGroup', 'endTime', 'id', 'lastUpdatedTime', 'meteringPointCount', 'municipalityNumber', 'name', 'nameNo', 'quantityKwh', 'startTime', 'type']
# Total rows: 25776
#
# Starting data extraction for consumption group: business
# API call: 2025-07-13 → 2025-07-14 for group 'business'
#   361 records processed for date 2025-07-13
# API call: 2025-07-14 → 2025-07-15 for group 'business'
#   361 records processed for date 2025-07-14
# API call: 2025-07-15 → 2025-07-16 for group 'business'
#   361 records processed for date 2025-07-15
# API call: 2025-07-16 → 2025-07-17 for group 'business'
#   361 records processed for date 2025-07-16
# API call: 2025-07-17 → 2025-07-18 for group 'business'
#   361 records processed for date 2025-07-17
# Data saved to file: municipalities_group_business_consumption.csv
# Detected fieldnames: ['consumptionGroup', 'endTime', 'id', 'lastUpdatedTime', 'meteringPointCount', 'municipalityNumber', 'name', 'nameNo', 'quantityKwh', 'startTime', 'type']
# Total rows: 25776

# %%
df_collect_private_consump=pd.read_csv('municipalities_group_private_consumption.csv')
df_collect_private_consump

# %%
df_collect_private_consump = df_collect_private_consump.drop(columns=['lastUpdatedTime', 'nameNo']) # Drop unnecessary columns

# %%
df_collect_private_consump
# Out:
#                   type    id  municipalityNumber                name  \
# 0         municipality     0                   0  Ukjent tilhørighet
# 1         municipality     0                   0  Ukjent tilhørighet
# 2         municipality     0                   0  Ukjent tilhørighet
# 3         municipality     0                   0  Ukjent tilhørighet
# 4         municipality     0                   0  Ukjent tilhørighet
# ...                ...   ...                 ...                 ...
# 13798389  municipality  5636                5636             Unjárga
# 13798390  municipality  5636                5636             Unjárga
# 13798391  municipality  5636                5636             Unjárga
# 13798392  municipality  5636                5636             Unjárga
# 13798393  municipality  5636                5636             Unjárga
#
#                           startTime                    endTime  \
# 0         2021-01-01T00:00:00+01:00  2021-01-01T01:00:00+01:00
# 1         2021-01-01T01:00:00+01:00  2021-01-01T02:00:00+01:00
# 2         2021-01-01T02:00:00+01:00  2021-01-01T03:00:00+01:00
# 3         2021-01-01T03:00:00+01:00  2021-01-01T04:00:00+01:00
# 4         2021-01-01T04:00:00+01:00  2021-01-01T05:00:00+01:00
# ...                             ...                        ...
# 13798389  2025-05-25T19:00:00+02:00  2025-05-25T20:00:00+02:00
# 13798390  2025-05-25T20:00:00+02:00  2025-05-25T21:00:00+02:00
# 13798391  2025-05-25T21:00:00+02:00  2025-05-25T22:00:00+02:00
# 13798392  2025-05-25T22:00:00+02:00  2025-05-25T23:00:00+02:00
# 13798393  2025-05-25T23:00:00+02:00  2025-05-26T00:00:00+02:00
#
#          consumptionGroup  quantityKwh  meteringPointCount
# 0                 private     3804.885                1721
# 1                 private     3781.050                1721
# 2                 private     3694.389                1721
# 3                 private     3641.815                1721
# 4                 private     3553.285                1721
# ...                   ...          ...                 ...
# 13798389          private      857.770                 614
# 13798390          private      905.987                 614
# 13798391          private      940.450                 614
# 13798392          private      928.957                 614
# 13798393          private      866.176                 614
#
# [13798394 rows x 9 columns]

# %%
df_collect_business_consump=pd.read_csv('municipalities_group_business_consumption.csv')
df_collect_business_consump

# %%
df_collect_business_consump = df_collect_private_consump.drop(columns=['lastUpdatedTime', 'nameNo']) # Drop unnecessary columns

# %%
df_collect_business_consump
# Out:
#                   type    id  municipalityNumber                name  \
# 0         municipality     0                   0  Ukjent tilhørighet
# 1         municipality     0                   0  Ukjent tilhørighet
# 2         municipality     0                   0  Ukjent tilhørighet
# 3         municipality     0                   0  Ukjent tilhørighet
# 4         municipality     0                   0  Ukjent tilhørighet
# ...                ...   ...                 ...                 ...
# 13798389  municipality  5636                5636             Unjárga
# 13798390  municipality  5636                5636             Unjárga
# 13798391  municipality  5636                5636             Unjárga
# 13798392  municipality  5636                5636             Unjárga
# 13798393  municipality  5636                5636             Unjárga
#
#                           startTime                    endTime  \
# 0         2021-01-01T00:00:00+01:00  2021-01-01T01:00:00+01:00
# 1         2021-01-01T01:00:00+01:00  2021-01-01T02:00:00+01:00
# 2         2021-01-01T02:00:00+01:00  2021-01-01T03:00:00+01:00
# 3         2021-01-01T03:00:00+01:00  2021-01-01T04:00:00+01:00
# 4         2021-01-01T04:00:00+01:00  2021-01-01T05:00:00+01:00
# ...                             ...                        ...
# 13798389  2025-05-25T19:00:00+02:00  2025-05-25T20:00:00+02:00
# 13798390  2025-05-25T20:00:00+02:00  2025-05-25T21:00:00+02:00
# 13798391  2025-05-25T21:00:00+02:00  2025-05-25T22:00:00+02:00
# 13798392  2025-05-25T22:00:00+02:00  2025-05-25T23:00:00+02:00
# 13798393  2025-05-25T23:00:00+02:00  2025-05-26T00:00:00+02:00
#
#          consumptionGroup  quantityKwh  meteringPointCount
# 0                business     1839.879                 251
# 1                business     1813.372                 251
# 2                business     1892.385                 251
# 3                business     1912.907                 251
# 4                business     1922.656                 251
# ...                   ...          ...                 ...
# 13798389         business      637.193                 110
# 13798390         business      677.898                 110
# 13798391         business      651.606                 110
# 13798392         business      602.574                 110
# 13798393         business      614.947                 110
#
# [13798394 rows x 9 columns]

# %%
df_collect_industry_consump=pd.read_csv('municipalities_group_industry_consumption.csv')
df_collect_industry_consump

# %%
df_collect_industry_consump = df_collect_private_consump.drop(columns=['lastUpdatedTime', 'nameNo']) # Drop unnecessary columns

# %%
df_collect_industry_consump
# Out:
#                   type    id  municipalityNumber                name  \
# 0         municipality     0                   0  Ukjent tilhørighet
# 1         municipality     0                   0  Ukjent tilhørighet
# 2         municipality     0                   0  Ukjent tilhørighet
# 3         municipality     0                   0  Ukjent tilhørighet
# 4         municipality     0                   0  Ukjent tilhørighet
# ...                ...   ...                 ...                 ...
# 13789797  municipality  5636                5636             Unjárga
# 13789798  municipality  5636                5636             Unjárga
# 13789799  municipality  5636                5636             Unjárga
# 13789800  municipality  5636                5636             Unjárga
# 13789801  municipality  5636                5636             Unjárga
#
#                           startTime                    endTime  \
# 0         2021-01-01T00:00:00+01:00  2021-01-01T01:00:00+01:00
# 1         2021-01-01T01:00:00+01:00  2021-01-01T02:00:00+01:00
# 2         2021-01-01T02:00:00+01:00  2021-01-01T03:00:00+01:00
# 3         2021-01-01T03:00:00+01:00  2021-01-01T04:00:00+01:00
# 4         2021-01-01T04:00:00+01:00  2021-01-01T05:00:00+01:00
# ...                             ...                        ...
# 13789797  2025-05-24T19:00:00+02:00  2025-05-24T20:00:00+02:00
# 13789798  2025-05-24T20:00:00+02:00  2025-05-24T21:00:00+02:00
# 13789799  2025-05-24T21:00:00+02:00  2025-05-24T22:00:00+02:00
# 13789800  2025-05-24T22:00:00+02:00  2025-05-24T23:00:00+02:00
# 13789801  2025-05-24T23:00:00+02:00  2025-05-25T00:00:00+02:00
#
#          consumptionGroup  quantityKwh  meteringPointCount
# 0                industry    11634.323                 130
# 1                industry    11581.860                 130
# 2                industry    11737.925                 130
# 3                industry    12749.224                 130
# 4                industry    12560.854                 130
# ...                   ...          ...                 ...
# 13789797         industry       92.598                  19
# 13789798         industry       92.398                  19
# 13789799         industry       93.325                  19
# 13789800         industry       95.736                  19
# 13789801         industry      104.737                  19
#
# [13789802 rows x 9 columns]

# %%
df_collect_private_consump.name.unique() # Get unique names in the 'name' column of the private consumption DataFrame
# Out:
# array(['Ukjent tilhørighet', 'Oslo', 'Eigersund', 'Stavanger',
#        'Haugesund', 'Sandnes', 'Sokndal', 'Lund', 'Bjerkreim', 'Hå',
#        'Klepp', 'Time', 'Gjesdal', 'Sola', 'Randaberg', 'Strand',
#        'Hjelmeland', 'Suldal', 'Sauda', 'Kvitsøy', 'Bokn', 'Tysvær',
#        'Karmøy', 'Utsira', 'Vindafjord', 'Kristiansund', 'Molde',
#        'Ålesund', 'Vanylven', 'Sande', 'Herøy', 'Ulstein', 'Hareid',
#        'Ørsta', 'Stranda', 'Sykkylven', 'Sula', 'Giske', 'Vestnes',
#        'Rauma', 'Aukra', 'Averøy', 'Gjemnes', 'Tingvoll', 'Sunndal',
#        'Surnadal', 'Smøla', 'Aure', 'Volda', 'Fjord', 'Hustadvika',
#        'Haram', 'Bodø', 'Narvik', 'Bindal', 'Sømna', 'Brønnøy', 'Vega',
#        'Vevelstad', 'Alstahaug', 'Leirfjord', 'Vefsn', 'Grane',
#        'Aarborte', 'Dønna', 'Nesna', 'Hemnes', 'Rana', 'Lurøy', 'Træna',
#        'Rødøy', 'Meløy', 'Gildeskål', 'Beiarn', 'Saltdal', 'Fauske',
#        'Sørfold', 'Steigen', 'Lødingen', 'Evenes', 'Røst', 'Værøy',
#        'Flakstad', 'Vestvågøy', 'Vågan', 'Hadsel', 'Bø', 'Øksnes',
#        'Sortland', 'Andøy', 'Moskenes', 'Hábmer', 'Halden', 'Moss',
#        'Sarpsborg', 'Fredrikstad', 'Hvaler', 'Råde', 'Våler', 'Skiptvet',
#        'Indre Østfold', 'Rakkestad', 'Marker', 'Aremark', 'Bærum',
#        'Asker', 'Lillestrøm', 'Nordre Follo', 'Ullensaker', 'Nesodden',
#        'Frogn', 'Vestby', 'Ås', 'Enebakk', 'Lørenskog', 'Rælingen',
#        'Aurskog-Høland', 'Nes', 'Gjerdrum', 'Nittedal', 'Lunner',
#        'Jevnaker', 'Nannestad', 'Eidsvoll', 'Hurdal', 'Drammen',
#        'Kongsberg', 'Ringerike', 'Hole', 'Lier', 'Øvre Eiker', 'Modum',
#        'Krødsherad', 'Flå', 'Nesbyen', 'Gol', 'Hemsedal', 'Ål', 'Hol',
#        'Sigdal', 'Flesberg', 'Rollag', 'Nore og Uvdal', 'Kongsvinger',
#        'Hamar', 'Lillehammer', 'Gjøvik', 'Ringsaker', 'Løten', 'Stange',
#        'Nord-Odal', 'Sør-Odal', 'Eidskog', 'Grue', 'Åsnes', 'Elverum',
#        'Trysil', 'Åmot', 'Stor-Elvdal', 'Rendalen', 'Engerdal', 'Tolga',
#        'Tynset', 'Alvdal', 'Folldal', 'Os', 'Dovre', 'Lesja', 'Skjåk',
#        'Lom', 'Vågå', 'Nord-Fron', 'Sel', 'Sør-Fron', 'Ringebu', 'Øyer',
#        'Gausdal', 'Østre Toten', 'Vestre Toten', 'Gran', 'Søndre Land',
#        'Nordre Land', 'Sør-Aurdal', 'Etnedal', 'Nord-Aurdal',
#        'Vestre Slidre', 'Øystre Slidre', 'Vang', 'Horten', 'Holmestrand',
#        'Tønsberg', 'Sandefjord', 'Larvik', 'Færder', 'Porsgrunn', 'Skien',
#        'Notodden', 'Siljan', 'Bamble', 'Kragerø', 'Drangedal', 'Nome',
#        'Midt-Telemark', 'Seljord', 'Hjartdal', 'Tinn', 'Kviteseid',
#        'Nissedal', 'Fyresdal', 'Tokke', 'Vinje', 'Risør', 'Grimstad',
#        'Arendal', 'Kristiansand', 'Lindesnes', 'Farsund', 'Flekkefjord',
#        'Gjerstad', 'Vegårshei', 'Tvedestrand', 'Froland', 'Lillesand',
#        'Birkenes', 'Åmli', 'Iveland', 'Evje og Hornnes', 'Bygland',
#        'Valle', 'Bykle', 'Vennesla', 'Åseral', 'Lyngdal', 'Hægebostad',
#        'Kvinesdal', 'Sirdal', 'Bergen', 'Kinn', 'Etne', 'Sveio', 'Bømlo',
#        'Stord', 'Fitjar', 'Tysnes', 'Kvinnherad', 'Ullensvang',
#        'Eidfjord', 'Ulvik', 'Voss', 'Kvam', 'Samnanger', 'Bjørnafjorden',
#        'Austevoll', 'Øygarden', 'Askøy', 'Vaksdal', 'Modalen', 'Osterøy',
#        'Alver', 'Austrheim', 'Fedje', 'Masfjorden', 'Gulen', 'Solund',
#        'Hyllestad', 'Høyanger', 'Vik', 'Sogndal', 'Aurland', 'Lærdal',
#        'Årdal', 'Luster', 'Askvoll', 'Fjaler', 'Sunnfjord', 'Bremanger',
#        'Stad', 'Gloppen', 'Stryn', 'Trondheim', 'Steinkjer', 'Namsos',
#        'Frøya', 'Osen', 'Oppdal', 'Rennebu', 'Rosse', 'Holtålen',
#        'Midtre Gauldal', 'Melhus', 'Skaun', 'Malvik', 'Selbu', 'Tydal',
#        'Meråker', 'Stjørdal', 'Frosta', 'Levanger', 'Verdal', 'Snåase',
#        'Lierne', 'Raarvihke', 'Namsskogan', 'Grong', 'Høylandet',
#        'Overhalla', 'Flatanger', 'Leka', 'Inderøy', 'Indre Fosen', 'Heim',
#        'Hitra', 'Ørland', 'Åfjord', 'Orkland', 'Nærøysund', 'Rindal',
#        'Tromsø', 'Harstad', 'Kvæfjord', 'Dielddanuorri', 'Ibestad',
#        'Gratangen', 'Loabák', 'Bardu', 'Salangen', 'Målselv', 'Sørreisa',
#        'Dyrøy', 'Senja', 'Balsfjord', 'Karlsøy', 'Lyngen', 'Storfjord',
#        'Gáivuotna', 'Skjervøy', 'Nordreisa', 'Kvænangen', 'Alta',
#        'Hammerfest', 'Sør-Varanger', 'Vadsø', 'Kárášjohka',
#        'Guovdageaidnu', 'Loppa', 'Hasvik', 'Måsøy', 'Nordkapp',
#        'Porsanger', 'Lebesby', 'Gamvik', 'Deatnu', 'Berlevåg',
#        'Båtsfjord', 'Vardø', 'Unjárga'], dtype=object)

# %%
consump_private_alesund=df_collect_private_consump[df_collect_private_consump['name']=='Ålesund'] # Filter data for Ålesund municipality
consump_private_alesund
# Out:
#                   type    id  municipalityNumber     name  \
# 648       municipality  1508                1508  Ålesund
# 649       municipality  1508                1508  Ålesund
# 650       municipality  1508                1508  Ålesund
# 651       municipality  1508                1508  Ålesund
# 652       municipality  1508                1508  Ålesund
# ...                ...   ...                 ...      ...
# 13790469  municipality  1508                1508  Ålesund
# 13790470  municipality  1508                1508  Ålesund
# 13790471  municipality  1508                1508  Ålesund
# 13790472  municipality  1508                1508  Ålesund
# 13790473  municipality  1508                1508  Ålesund
#
#                           startTime                    endTime  \
# 648       2021-01-01T00:00:00+01:00  2021-01-01T01:00:00+01:00
# 649       2021-01-01T01:00:00+01:00  2021-01-01T02:00:00+01:00
# 650       2021-01-01T02:00:00+01:00  2021-01-01T03:00:00+01:00
# 651       2021-01-01T03:00:00+01:00  2021-01-01T04:00:00+01:00
# 652       2021-01-01T04:00:00+01:00  2021-01-01T05:00:00+01:00
# ...                             ...                        ...
# 13790469  2025-05-25T19:00:00+02:00  2025-05-25T20:00:00+02:00
# 13790470  2025-05-25T20:00:00+02:00  2025-05-25T21:00:00+02:00
# 13790471  2025-05-25T21:00:00+02:00  2025-05-25T22:00:00+02:00
# 13790472  2025-05-25T22:00:00+02:00  2025-05-25T23:00:00+02:00
# 13790473  2025-05-25T23:00:00+02:00  2025-05-26T00:00:00+02:00
#
#          consumptionGroup  quantityKwh  meteringPointCount
# 648               private    58370.730               27060
# 649               private    57961.562               27060
# 650               private    56258.645               27060
# 651               private    54556.203               27060
# 652               private    53356.273               27060
# ...                   ...          ...                 ...
# 13790469          private    45866.402               29305
# 13790470          private    47126.195               29305
# 13790471          private    46556.260               29305
# 13790472          private    45021.470               29305
# 13790473          private    41975.350               29305
#
# [38543 rows x 9 columns]

# %%
consump_industry_alesund=df_collect_industry_consump[df_collect_industry_consump['name']=='Ålesund'] # Filter data for Ålesund municipality
consump_industry_alesund
# Out:
#                   type    id  municipalityNumber     name  \
# 648       municipality  1508                1508  Ålesund
# 649       municipality  1508                1508  Ålesund
00
#
#          consumptionGroup  quantityKwh  meteringPointCount
# 648              business    30526.664                3784
# 649              business    30582.870                3784
# 650              business    30352.254                3784
# 651              business    30774.594                3784
# 652              business    30846.584                3784
# ...                   ...          ...                 ...
# 13790469         business    26713.293                3373
# 13790470         business    26257.412                3373
# 13790471         business    26194.588                3373
# 13790472         business    25590.326                3373
# 13790473         business    26210.523                3373
#
# [38543 rows x 9 columns]

# %%
consump_private_alesund.loc[:, 'startTime'] = pd.to_datetime(consump_private_alesund.loc[:, 'startTime'], utc=True) # Convert startTime to datetime with UTC bcause the API returns it + time zone
consump_private_alesund.loc[:, 'endTime'] = pd.to_datetime(consump_private_alesund.loc[:, 'endTime'], utc=True) 
consump_private_alesund
# Out:
#                   type    id  municipalityNumber     name  \
# 648       municipality  1508                1508  Ålesund
# 649       municipality  1508                1508  Ålesund
# 650       municipality  1508                1508  Ålesund
# 651       municipality  1508                1508  Ålesund
# 652       municipality  1508                1508  Ålesund
# ...                ...   ...                 ...      ...
# 13790469  municipality  1508                1508  Ålesund
# 13790470  municipality  1508                1508  Ålesund
# 13790471  municipality  1508                1508  Ålesund
# 13790472  municipality  1508                1508  Ålesund
# 13790473  municipality  1508                1508  Ålesund
#
#                           startTime                    endTime  \
# 648       2020-12-31 23:00:00+00:00  2021-01-01 00:00:00+00:00
# 649       2021-01-01 00:00:00+00:00  2021-01-01 01:00:00+00:00
# 650       2021-01-01 01:00:00+00:00  2021-01-01 02:00:00+00:00
# 651       2021-01-01 02:00:00+00:00  2021-01-01 03:00:00+00:00
# 652       2021-01-01 03:00:00+00:00  2021-01-01 04:00:00+00:00
# ...                             ...                        ...
# 13790469  2025-05-25 17:00:00+00:00  2025-05-25 18:00:00+00:00
# 13790470  2025-05-25 18:00:00+00:00  2025-05-25 19:00:00+00:00
# 13790471  2025-05-25 19:00:00+00:00  2025-05-25 20:00:00+00:00
# 13790472  2025-05-25 20:00:00+00:00  2025-05-25 21:00:00+00:00
# 13790473  2025-05-25 21:00:00+00:00  2025-05-25 22:00:00+00:00
#
#          consumptionGroup  quantityKwh  meteringPointCount
# 648               private    58370.730               27060
# 649               private    57961.562               27060
# 650               private    56258.645               27060
# 651               private    54556.203               27060
# 652               private    53356.273               27060
# ...                   ...          ...                 ...
# 13790469          private    45866.402               29305
# 13790470          private    47126.195               29305
# 13790471          private    46556.260               29305
# 13790472          private    45021.470               29305
# 13790473          private    41975.350               29305
#
# [38543 rows x 9 columns]

# %%
nan_par_colonne = consump_private_alesund.isna().sum()  # Count NaN values in each column
print(nan_par_colonne)
# Out:
# type                  0
# id                    0
# municipalityNumber    0
# name                  0
# startTime             0
# endTime               0
# consumptionGroup      0
# quantityKwh           0
# meteringPointCount    0
# dtype: int64

# %%
nbr_doublons = consump_private_alesund['startTime'].duplicated().sum() # Count the number of duplicate entries in the 'startTime' column
print("Nombre de doublons dans startTime :", nbr_doublons)
# Out:
# Nombre de doublons dans startTime : 0

# %%
consump_business_alesund.loc[:, 'startTime'] = pd.to_datetime(consump_business_alesund.loc[:, 'startTime'], utc=True)
consump_business_alesund.loc[:, 'endTime'] = pd.to_datetime(consump_business_alesund.loc[:, 'endTime'], utc=True)
consump_business_alesund
# Out:
#                   type    id  municipalityNumber     name  \
# 648       municipality  1508                1508  Ålesund
# 649       municipality  1508                1508  Ålesund
# 650       municipality  1508                1508  Ålesund
# 651       municipality  1508                1508  Ålesund
# 652       municipality  1508                1508  Ålesund
# ...                ...   ...                 ...      ...
# 13790469  municipality  1508                1508  Ålesund
# 13790470  municipality  1508                1508  Ålesund
# 13790471  municipality  1508                1508  Ålesund
# 13790472  municipality  1508                1508  Ålesund
# 13790473  municipality  1508                1508  Ålesund
#
#                           startTime                    endTime  \
# 648       2020-12-31 23:00:00+00:00  2021-01-01 00:00:00+00:00
# 649       2021-01-01 00:00:00+00:00  2021-01-01 01:00:00+00:00
# 650       2021-01-01 01:00:00+00:00  2021-01-01 02:00:00+00:00
# 651       2021-01-01 02:00:00+00:00  2021-01-01 03:00:00+00:00
# 652       2021-01-01 03:00:00+00:00  2021-01-01 04:00:00+00:00
# ...                             ...                        ...
# 13790469  2025-05-25 17:00:00+00:00  2025-05-25 18:00:00+00:00
# 13790470  2025-05-25 18:00:00+00:00  2025-05-25 19:00:00+00:00
# 13790471  2025-05-25 19:00:00+00:00  2025-05-25 20:00:00+00:00
# 13790472  2025-05-25 20:00:00+00:00  2025-05-25 21:00:00+00:00
# 13790473  2025-05-25 21:00:00+00:00  2025-05-25 22:00:00+00:00
#
#          consumptionGroup  quantityKwh  meteringPointCount
# 648              business    30526.664                3784
# 649              business    30582.870                3784
# 650              business    30352.254                3784
# 651              business    30774.594                3784
# 652              business    30846.584                3784
# ...                   ...          ...                 ...
# 13790469         business    26713.293                3373
# 13790470         business    26257.412                3373
# 13790471         business    26194.588                3373
# 13790472         business    25590.326                3373
# 13790473         business    26210.523                3373
#
# [38543 rows x 9 columns]

# %%
nan_par_colonne = consump_business_alesund.isna().sum()
print(nan_par_colonne)
# Out:
# type                  0
# id                    0
# municipalityNumber    0
# name                  0
# startTime             0
# endTime               0
# consumptionGroup      0
# quantityKwh           0
# meteringPointCount    0
# dtype: int64

# %%
nbr_doublons = consump_business_alesund['startTime'].duplicated().sum()  # Count the number of duplicate entries in the 'startTime' column
print("Nombre de doublons dans startTime :", nbr_doublons)
# Out:
# Nombre de doublons dans startTime : 0

# %%
consump_industry_alesund.loc[:, 'startTime'] = pd.to_datetime(consump_industry_alesund.loc[:, 'startTime'], utc=True)
consump_industry_alesund.loc[:, 'endTime'] = pd.to_datetime(consump_industry_alesund.loc[:, 'endTime'], utc=True)
consump_industry_alesund
# Out:
#                   type    id  municipalityNumber     name  \
# 648       municipality  1508                1508  Ålesund
# 649       municipality  1508                1508  Ålesund
# 650       municipality  1508                1508  Ålesund
# 651       municipality  1508                1508  Ålesund
# 652       municipality  1508                1508  Ålesund
# ...                ...   ...                 ...      ...
# 13781877  municipality  1508                1508  Ålesund
# 13781878  municipality  1508                1508  Ålesund
# 13781879  municipality  1508                1508  Ålesund
# 13781880  municipality  1508                1508  Ålesund
# 13781881  municipality  1508                1508  Ålesund
#
#                           startTime                    endTime  \
# 648       2020-12-31 23:00:00+00:00  2021-01-01 00:00:00+00:00
# 649       2021-01-01 00:00:00+00:00  2021-01-01 01:00:00+00:00
# 650       2021-01-01 01:00:00+00:00  2021-01-01 02:00:00+00:00
# 651       2021-01-01 02:00:00+00:00  2021-01-01 03:00:00+00:00
# 652       2021-01-01 03:00:00+00:00  2021-01-01 04:00:00+00:00
# ...                             ...                        ...
# 13781877  2025-05-24 17:00:00+00:00  2025-05-24 18:00:00+00:00
# 13781878  2025-05-24 18:00:00+00:00  2025-05-24 19:00:00+00:00
# 13781879  2025-05-24 19:00:00+00:00  2025-05-24 20:00:00+00:00
# 13781880  2025-05-24 20:00:00+00:00  2025-05-24 21:00:00+00:00
# 13781881  2025-05-24 21:00:00+00:00  2025-05-24 22:00:00+00:00
#
#          consumptionGroup  quantityKwh  meteringPointCount
# 648              industry    13259.716                1029
# 649              industry    13558.855                1029
# 650              industry    13649.810                1029
# 651              industry    13533.480                1029
# 652              industry    13484.362                1029
# ...                   ...          ...                 ...
# 13781877         industry    18226.408                 842
# 13781878         industry    17460.377                 842
# 13781879         industry    17923.867                 842
# 13781880         industry    17545.988                 842
# 13781881         industry    17578.795                 842
#
# [38519 rows x 9 columns]

# %%
nan_par_colonne = consump_industry_alesund.isna().sum()
print(nan_par_colonne)
# Out:
# type                  0
# id                    0
# municipalityNumber    0
# name                  0
# startTime             0
# endTime               0
# consumptionGroup      0
# quantityKwh           0
# meteringPointCount    0
# dtype: int64

# %%
nbr_doublons = consump_industry_alesund['startTime'].duplicated().sum() 
print("Nombre de doublons dans startTime :", nbr_doublons)
# Out:
# Nombre de doublons dans startTime : 0

# %%
# Extraire les dates de chaque groupe 
dates1 = set(consump_business_alesund['startTime'])
dates2 = set(consump_industry_alesund['startTime'])
dates3 = set(consump_private_alesund['startTime'])

# Intersection des dates
dates_communes = dates1 & dates2 & dates3
groupe1_filtré = consump_private_alesund[consump_private_alesund['startTime'].isin(dates_communes)]
groupe2_filtré = consump_business_alesund[consump_business_alesund['startTime'].isin(dates_communes)]
groupe3_filtré = consump_industry_alesund[consump_industry_alesund['startTime'].isin(dates_communes)]
# Concaténation des DataFrames filtrés
resultat = pd.concat([groupe1_filtré, groupe2_filtré, groupe3_filtré])
resultat = resultat.sort_values(by='startTime')
resultat
# Out:
#                   type    id  municipalityNumber     name  \
# 648       municipality  1508                1508  Ålesund
# 648       municipality  1508                1508  Ålesund
# 648       municipality  1508                1508  Ålesund
# 649       municipality  1508                1508  Ålesund
# 649       municipality  1508                1508  Ålesund
# ...                ...   ...                 ...      ...
# 13781880  municipality  1508                1508  Ålesund
# 13781880  municipality  1508                1508  Ålesund
# 13781881  municipality  1508                1508  Ålesund
# 13781881  municipality  1508                1508  Ålesund
# 13781881  municipality  1508                1508  Ålesund
#
#                           startTime                    endTime  \
# 648       2020-12-31 23:00:00+00:00  2021-01-01 00:00:00+00:00
# 648       2020-12-31 23:00:00+00:00  2021-01-01 00:00:00+00:00
# 648       2020-12-31 23:00:00+00:00  2021-01-01 00:00:00+00:00
# 649       2021-01-01 00:00:00+00:00  2021-01-01 01:00:00+00:00
# 649       2021-01-01 00:00:00+00:00  2021-01-01 01:00:00+00:00
# ...                             ...                        ...
# 13781880  2025-05-24 20:00:00+00:00  2025-05-24 21:00:00+00:00
# 13781880  2025-05-24 20:00:00+00:00  2025-05-24 21:00:00+00:00
# 13781881  2025-05-24 21:00:00+00:00  2025-05-24 22:00:00+00:00
# 13781881  2025-05-24 21:00:00+00:00  2025-05-24 22:00:00+00:00
# 13781881  2025-05-24 21:00:00+00:00  2025-05-24 22:00:00+00:00
#
#          consumptionGroup  quantityKwh  meteringPointCount
# 648               private    58370.730               27060
# 648              industry    13259.716                1029
# 648              business    30526.664                3784
# 649               private    57961.562               27060
# 649              industry    13558.855                1029
# ...                   ...          ...                 ...
# 13781880          private    47385.406               29305
# 13781880         business    24504.025                3373
# 13781881         business    25000.594                3373
# 13781881          private    46403.700               29305
# 13781881         industry    17578.795                 842
#
# [115557 rows x 9 columns]

# %%
resultat.to_csv("consommation_Alesund_per_group.csv", index=False) # Save the result to a CSV file

# %% [markdown]
# ### Extraction des groupes de consommation
# ### Contexte et objectif
# l'extraction des groupes de consommation disponibles via l'API Elhub. Cette étape est cruciale pour comprendre quels types de consommateurs existent dans le système avant de procéder à l'extraction des données détaillées.
#
# Avantages :
#
# Adaptabilité : Fonctionne même si l'API ajoute de nouveaux champs
#
# Maintenabilité : Aucune modification de code nécessaire pour de nouveaux attributs

# %%
headers = {
    
} # Make a request to the Elhub API to get consumption groups data

response = requests.get('https://api.elhub.no/energy-data/v0/consumption-groups', headers=headers)  # Check if the request was successful
if response.status_code == 200: # Check if the request was successful
    json_data = response.json()
    data_list = json_data.get("data", [])

    rows = []
    all_keys = set()

    # Parcours des objets JSON pour extraire toutes les clés
    for item in data_list:
        flat_item = {}
        for key, value in item.items():
            if isinstance(value, dict): 
                for sub_key, sub_value in value.items(): # Check if the value is a dictionary
                    flat_item[sub_key] = sub_value
                    all_keys.add(sub_key)
            else:
                flat_item[key] = value
                all_keys.add(key)
        rows.append(flat_item)

    # Génération CSV avec les en-têtes détectées dynamiquement
    if rows:
        with open("groupes_de_consommation.csv", mode="w", newline='', encoding="utf-8") as file:
            writer = csv.DictWriter(file, fieldnames=sorted(all_keys))
            writer.writeheader()
            writer.writerows(rows)
        print(" Données exportées dans groupes_de_consommation.csv")
    else:
        print(" Aucune donnée trouvée.")
else:
    print(" Échec de l'appel API :", response.status_code) # Print error if the API call was not successful
# Out:
#  Données exportées dans groupes_de_consommation.csv

# %%
df_collect_groupe=pd.read_csv('groupes_de_consommation.csv')
df_collect_groupe
# Out:
#                                          description         id  \
# 0  Meteringpoints that either have NACE Code XX (...  household
# 1                  Cabins and vacation homes nace XY      cabin
# 2  All agriculture, forestry, fishing incl green ...    primary
# 3             All industry section codes B through F  secondary
# 4  All section codes G through U. Also includes a...   tertiary
# 5      Combination of Primary and Secondary Industry   industry
# 6                 Combination of Household and Cabin    private
# 7                          Same as Tertiary Industry   business
# 8                                                  *          *
#
#                             name                type
# 0                      Household  consumption-groups
# 1  Cabins and holiday properties  consumption-groups
# 2               Primary Industry  consumption-groups
# 3             Secondary Industry  consumption-groups
# 4              Tertiary Industry  consumption-groups
# 5                       Industry  consumption-groups
# 6                        Private  consumption-groups
# 7                       Business  consumption-groups
# 8                              *  consumption-groups

# %% [markdown]
# Ce code configure les paramètres nécessaires pour collecter des données de consommation énergétique via l'API Elhub
#
# Type de données : Consommation par groupe MBA par heure
#
# Format : Respecter la casse exacte exigée par l'API
#
# Description : Collecte les données de consommation électrique agrégées par groupes de zones de prix (MBA - Market Balance Area)
#
# Authentification : Vérifiez que vous disposez des credentials appropriés pour accéder à l'API Elhub
#
# Limites de l'API : Respectez les quotas et limites de taux imposés par Elhub
#
# Format des données : Les données seront structurées selon le schéma MBA (Market Balance Area)
#
# Mise à jour : La date de fin est dynamique et correspond toujours au moment d'exécution

# %%
# Constantes
dataset = "CONSUMPTION_PER_GROUP_MBA_HOUR"  # Respecter la casse exacte exigée par l'API
base_url = "https://api.elhub.no/energy-data/v0/price-areas" # Base URL for the API endpoint

# Dates de début et de fin
start_date = datetime(2020, 1, 1)  # Date de début pour la collecte de données autorisée par l'API
end_limit = datetime.now()

# Fichier de sortie
file_name = "consumption_price_areas.csv"

# Initialiser les collections pour stocker toutes les données
all_rows = []              # Liste pour stocker toutes les lignes de données  
all_fieldnames = set()                       # Ensemble pour collecter automatiquement tous les en-têtes possibles

# Boucle principale pour traiter chaque jour
current_date = start_date      # Initialize current date to start date will be incremented day by day    
while current_date < end_limit: 
    end_date = current_date + timedelta(days=1)            

    # Format des dates pour l'URL
    start_str = current_date.strftime("%Y-%m-%d")
    end_str = end_date.strftime("%Y-%m-%d")

    # Construction de l'URL API
    url = (
        f"{base_url}?dataset={dataset}"
        f"&startDate={start_str}"
        f"&endDate={end_str}"
    )

    print(f"Appel API : {start_str} → {end_str}")

    try:
        # Effectuer la requête API
        response = requests.get(url)
        
        if response.status_code == 200:
            json_full = response.json()
            data = json_full.get("data", [])
            
            # Traiter chaque élément de données
            for item in data:
                if not isinstance(item, dict):
                    continue
                
                # Structure de base de l'item
                base_row = {
                    "type": item.get("type"), 
                    "id": item.get("id")
                }
                
                attr = item.get("attributes", {})    # Extraire le champ "attributes", par défaut un dictionnaire vide si non présent
                
                # Ajouter automatiquement tous les attributs au niveau municipality 
                for attr_key, attr_value in attr.items():
                    if attr_key != "consumptionPerGroupMbaHour":
                        base_row[attr_key] = attr_value 
                
                # Traiter les données de consommation horaire
                for record in attr.get("consumptionPerGroupMbaHour", []):
                    # Créer une ligne complète en combinant les infos de base et les données horaires
                    row = {**base_row}  # Copier les données de base
                    
                    # Ajouter automatiquement toutes les données du record
                    for record_key, record_value in record.items():
                        row[record_key] = record_value
                    
                    # Ajouter toutes les clés trouvées à notre ensemble d'en-têtes
                    all_fieldnames.update(row.keys())
                    all_rows.append(row)
            
            if data:
                print(f"  {len(data)} records processed for date {start_str}")
            else:
                print(f"  No data for date {start_str}")
                
        else:
            print(f"API call failed with status code: {response.status_code}")
            print(f"Response: {response.text}")
            
    except Exception as e:
        print(f"API error: {e}")
    
    # Passer au jour suivant
    current_date = end_date       # Increment the current date by one day to process the next date
    time.sleep(1)  # Pause pour éviter les limitations de taux

# Écrire toutes les données dans le fichier CSV
if all_rows:
    with open(file_name, mode="w", newline="", encoding="utf-8") as file:
        # Trier les en-têtes pour avoir un ordre cohérent
        sorted_fieldnames = sorted(all_fieldnames)
        writer = csv.DictWriter(file, fieldnames=sorted_fieldnames)
        writer.writeheader()
        writer.writerows(all_rows)
    
    print(f"\nData saved to file: {file_name}")
    print(f"Detected fieldnames: {sorted_fieldnames}")
    print(f"Total rows: {len(all_rows)}")
else:
    print("No data found in the specified date range")
# Out:
#  Appel API : 2020-01-01 → 2020-01-02
#  Aucune donnée pour 2020-01-01
#  Appel API : 2020-01-02 → 2020-01-03
#  Aucune donnée pour 2020-01-02
#  Appel API : 2020-01-03 → 2020-01-04
#  Aucune donnée pour 2020-01-03
#  Appel API : 2020-01-04 → 2020-01-05
#  Aucune donnée pour 2020-01-04
#  Appel API : 2020-01-05 → 2020-01-06
#  Aucune donnée pour 2020-01-05
#  Appel API : 2020-01-06 → 2020-01-07
#  Aucune donnée pour 2020-01-06
#  Appel API : 2020-01-07 → 2020-01-08
#  Aucune donnée pour 2020-01-07
#  Appel API : 2020-01-08 → 2020-01-09
#  Aucune donnée pour 2020-01-08
#  Appel API : 2020-01-09 → 2020-01-10
#  Aucune donnée pour 2020-01-09
#  Appel API : 2020-01-10 → 2020-01-11
#  Aucune donnée pour 2020-01-10
#  Appel API : 2020-01-11 → 2020-01-12
#  Aucune donnée pour 2020-01-11
#  Appel API : 2020-01-12 → 2020-01-13
#  Aucune donnée pour 2020-01-12
#  Appel API : 2020-01-13 → 2020-01-14
#  Aucune donnée pour 2020-01-13
#  Appel API : 2020-01-14 → 2020-01-15
#  Aucune donnée pour 2020-01-14
#  Appel API : 2020-01-15 → 2020-01-16
#  Aucune donnée pour 2020-01-15
#  Appel API : 2020-01-16 → 2020-01-17
#  Aucune donnée pour 2020-01-16
#  Appel API : 2020-01-17 → 2020-01-18
#  Aucune donnée pour 2020-01-17
#  Appel API : 2020-01-18 → 2020-01-19
#  Aucune donnée pour 2020-01-18
#  Appel API : 2020-01-19 → 2020-01-20
#  Aucune donnée pour 2020-01-19
#  Appel API : 2020-01-20 → 2020-01-21
#  Aucune donnée pour 2020-01-20
#  Appel API : 2020-01-21 → 2020-01-22
#  Aucune donnée pour 2020-01-21
#  Appel API : 2020-01-22 → 2020-01-23
#  Aucune donnée pour 2020-01-22
#  Appel API : 2020-01-23 → 2020-01-24
#  Aucune donnée pour 2020-01-23
#  Appel API : 2020-01-24 → 2020-01-25
#  Aucune donnée pour 2020-01-24
#  Appel API : 2020-01-25 → 2020-01-26
#  Aucune donnée pour 2020-01-25
#  Appel API : 2020-01-26 → 2020-01-27
#  Aucune donnée pour 2020-01-26
#  Appel API : 2020-01-27 → 2020-01-28
#  Aucune donnée pour 2020-01-27
#  Appel API : 2020-01-28 → 2020-01-29
#  Aucune donnée pour 2020-01-28
#  Appel API : 2020-01-29 → 2020-01-30
#  Aucune donnée pour 2020-01-29
#  Appel API : 2020-01-30 → 2020-01-31
#  Aucune donnée pour 2020-01-30
#  Appel API : 2021-01-21 → 2021-01-22
#  600 enregistrements ajoutés pour 2021-01-21
#  Appel API : 2021-01-22 → 2021-01-23
#  600 enregistrements ajoutés pour 2021-01-22
#  Appel API : 2021-01-23 → 2021-01-24
#  600 enregistrements ajoutés pour 2021-01-23
#  Appel API : 2021-01-24 → 2021-01-25
#  600 enregistrements ajoutés pour 2021-01-24
#  Appel API : 2021-01-25 → 2021-01-26
#  600 enregistrements ajoutés pour 2021-01-25
#  Appel API : 2021-01-26 → 2021-01-27
#  600 enregistrements ajoutés pour 2021-01-26
#  Appel API : 2021-01-27 → 2021-01-28
#  600 enregistrements ajoutés pour 2021-01-27
#  Appel API : 2021-01-28 → 2021-01-29
#  600 enregistrements ajoutés pour 2021-01-28
#  Appel API : 2021-01-29 → 2021-01-30
#  600 enregistrements ajoutés pour 2021-01-29
#  Appel API : 2021-01-30 → 2021-01-31
#  600 enregistrements ajoutés pour 2021-01-30
#  Appel API : 2021-01-31 → 2021-02-01
#  600 enregistrements ajoutés pour 2021-01-31
#  Appel API : 2021-02-01 → 2021-02-02
#  600 enregistrements ajoutés pour 2021-02-01
#  Appel API : 2021-02-02 → 2021-02-03
#  600 enregistrements ajoutés pour 2021-02-02
#  Appel API : 2021-02-03 → 2021-02-04
#  600 enregistrements ajoutés pour 2021-02-03
#  Appel API : 2021-02-04 → 2021-02-05
#  600 enregistrements ajoutés pour 2021-02-04
#  Appel API : 2021-02-05 → 2021-02-06
#  600 enregistrements ajoutés pour 2021-02-05
#  Appel API : 2021-02-06 → 2021-02-07
#  600 enregistrements ajoutés pour 2021-02-06
#  Appel API : 2021-02-07 → 2021-02-08
#  600 enregistrements ajoutés pour 2021-02-07
#  Appel API : 2021-02-08 → 2021-02-09
#  600 enregistrements ajoutés pour 2021-02-08
#  Appel API : 2021-02-09 → 2021-02-10
#  600 enregistrements ajoutés pour 2021-02-09
#  Appel API : 2021-02-10 → 2021-02-11
#  600 enregistrements ajoutés pour 2021-02-10
#  Appel API : 2021-02-11 → 2021-02-12
#  600 enregistrements ajoutés pour 2021-02-11
#  Appel API : 2021-02-12 → 2021-02-13
#  600 enregistrements ajoutés pour 2021-02-12
#  Appel API : 2021-02-13 → 2021-02-14
#  600 enregistrements ajoutés pour 2021-02-13
#  Appel API : 2021-02-14 → 2021-02-15
#  600 enregistrements ajoutés pour 2021-02-14
#  Appel API : 2021-02-15 → 2021-02-16
#  600 enregistrements ajoutés pour 2021-02-15
#  Appel API : 2021-02-16 → 2021-02-17
#  600 enregistrements ajoutés pour 2021-02-16
#  Appel API : 2021-02-17 → 2021-02-18
#  600 enregistrements ajoutés pour 2021-02-17
#  Appel API : 2021-02-18 → 2021-02-19
#  600 enregistrements ajoutés pour 2021-02-18
#  Appel API : 2021-02-19 → 2021-02-20
#  600 enregistrements ajoutés pour 2021-02-19
#  Appel API : 2021-02-20 → 2021-02-21
#  600 enregistrements ajoutés pour 2021-02-20
#  Appel API : 2021-02-21 → 2021-02-22
#  600 enregistrements ajoutés pour 2021-02-21
#  Appel API : 2021-02-22 → 2021-02-23
#  600 enregistrements ajoutés pour 2021-02-22
#  Appel API : 2021-02-23 → 2021-02-24
#  600 enregistrements ajoutés pour 2021-02-23
#  Appel API : 2021-02-24 → 2021-02-25
#  600 enregistrements ajoutés pour 2021-02-24
#  Appel API : 2021-02-25 → 2021-02-26
#  600 enregistrements ajoutés pour 2021-02-25
#  Appel API : 2021-02-26 → 2021-02-27
#  600 enregistrements ajoutés pour 2021-02-26
#  Appel API : 2021-02-27 → 2021-02-28
#  600 enregistrements ajoutés pour 2021-02-27
#  Appel API : 2021-02-28 → 2021-03-01
#  600 enregistrements ajoutés pour 2021-02-28
#  Appel API : 2021-03-01 → 2021-03-02
#  600 enregistrements ajoutés pour 2021-03-01
#  Appel API : 2021-03-02 → 2021-03-03
#  600 enregistrements ajoutés pour 2021-03-02
#  Appel API : 2021-03-03 → 2021-03-04
#  600 enregistrements ajoutés pour 2021-03-03
#  Appel API : 2021-03-04 → 2021-03-05
#  600 enregistrements ajoutés pour 2021-03-04
#  Appel API : 2021-03-05 → 2021-03-06
#  600 enregistrements ajoutés pour 2021-03-05
#  Appel API : 2021-03-06 → 2021-03-07
#  600 enregistrements ajoutés pour 2021-03-06
#  Appel API : 2021-03-07 → 2021-03-08
#  600 enregistrements ajoutés pour 2021-03-07
#  Appel API : 2021-03-08 → 2021-03-09
#  600 enregistrements ajoutés pour 2021-03-08
#  Appel API : 2021-03-09 → 2021-03-10
#  600 enregistrements ajoutés pour 2021-03-09
#  Appel API : 2021-03-10 → 2021-03-11
#  600 enregistrements ajoutés pour 2021-03-10
#  Appel API : 2021-03-11 → 2021-03-12
#  600 enregistrements ajoutés pour 2021-03-11
#  Appel API : 2021-03-12 → 2021-03-13
#  600 enregistrements ajoutés pour 2021-03-12
#  Appel API : 2021-03-13 → 2021-03-14
#  600 enregistrements ajoutés pour 2021-03-13
#  Appel API : 2021-03-14 → 2021-03-15
#  600 enregistrements ajoutés pour 2021-03-14
#  Appel API : 2021-03-15 → 2021-03-16
#  600 enregistrements ajoutés pour 2021-03-15
#  Appel API : 2021-03-16 → 2021-03-17
#  600 enregistrements ajoutés pour 2021-03-16
#  Appel API : 2021-03-17 → 2021-03-18
#  600 enregistrements ajoutés pour 2021-03-17
#  Appel API : 2021-03-18 → 2021-03-19
#  600 enregistrements ajoutés pour 2021-03-18
#  Appel API : 2021-03-19 → 2021-03-20
#  600 enregistrements ajoutés pour 2021-03-19
#  Appel API : 2021-03-20 → 2021-03-21
#  600 enregistrements ajoutés pour 2021-03-20
#  Appel API : 2021-03-21 → 2021-03-22
#  600 enregistrements ajoutés pour 2021-03-21
#  Appel API : 2021-03-22 → 2021-03-23
#  600 enregistrements ajoutés pour 2021-03-22
#  Appel API : 2021-03-23 → 2021-03-24
#  600 enregistrements ajoutés pour 2021-03-23
#  Appel API : 2021-03-24 → 2021-03-25
#  600 enregistrements ajoutés pour 2021-03-24
#  Appel API : 2021-03-25 → 2021-03-26
#  600 enregistrements ajoutés pour 2021-03-25
#  600 enregistrements ajoutés pour 2024-12-18
#  Appel API : 2024-12-19 → 2024-12-20
#  600 enregistrements ajoutés pour 2024-12-19
#  Appel API : 2024-12-20 → 2024-12-21
#  600 enregistrements ajoutés pour 2024-12-20
#  Appel API : 2024-12-21 → 2024-12-22
#  600 enregistrements ajoutés pour 2024-12-21
#  Appel API : 2024-12-22 → 2024-12-23
#  600 enregistrements ajoutés pour 2024-12-22
#  Appel API : 2024-12-23 → 2024-12-24
#  600 enregistrements ajoutés pour 2024-12-23
#  Appel API : 2024-12-24 → 2024-12-25
#  600 enregistrements ajoutés pour 2024-12-24
#  Appel API : 2024-12-25 → 2024-12-26
#  600 enregistrements ajoutés pour 2024-12-25
#  Appel API : 2024-12-26 → 2024-12-27
#  600 enregistrements ajoutés pour 2024-12-26
#  Appel API : 2024-12-27 → 2024-12-28
#  600 enregistrements ajoutés pour 2024-12-27
#  Appel API : 2024-12-28 → 2024-12-29
#  600 enregistrements ajoutés pour 2024-12-28
#  Appel API : 2024-12-29 → 2024-12-30
#  600 enregistrements ajoutés pour 2024-12-29
#  Appel API : 2024-12-30 → 2024-12-31
#  600 enregistrements ajoutés pour 2024-12-30
#  Appel API : 2024-12-31 → 2025-01-01
#  600 enregistrements ajoutés pour 2024-12-31
#  Appel API : 2025-01-01 → 2025-01-02
#  600 enregistrements ajoutés pour 2025-01-01
#  Appel API : 2025-01-02 → 2025-01-03
#  600 enregistrements ajoutés pour 2025-01-02
#  Appel API : 2025-01-03 → 2025-01-04
#  600 enregistrements ajoutés pour 2025-01-03
#  Appel API : 2025-01-04 → 2025-01-05
#  600 enregistrements ajoutés pour 2025-01-04
#  Appel API : 2025-01-05 → 2025-01-06
#  600 enregistrements ajoutés pour 2025-01-05
#  Appel API : 2025-01-06 → 2025-01-07
#  600 enregistrements ajoutés pour 2025-01-06
#  Appel API : 2025-01-07 → 2025-01-08
#  600 enregistrements ajoutés pour 2025-01-07
#  Appel API : 2025-01-08 → 2025-01-09
#  600 enregistrements ajoutés pour 2025-01-08
#  Appel API : 2025-01-09 → 2025-01-10
#  600 enregistrements ajoutés pour 2025-01-09
#  Appel API : 2025-01-10 → 2025-01-11
#  600 enregistrements ajoutés pour 2025-01-10
#  Appel API : 2025-01-11 → 2025-01-12
#  600 enregistrements ajoutés pour 2025-01-11
#  Appel API : 2025-01-12 → 2025-01-13
#  600 enregistrements ajoutés pour 2025-01-12
#  Appel API : 2025-01-13 → 2025-01-14
#  600 enregistrements ajoutés pour 2025-01-13
#  Appel API : 2025-01-14 → 2025-01-15
#  600 enregistrements ajoutés pour 2025-01-14
#  Appel API : 2025-01-15 → 2025-01-16
#  600 enregistrements ajoutés pour 2025-01-15
#  Appel API : 2025-01-16 → 2025-01-17
#  600 enregistrements ajoutés pour 2025-01-16
#  Appel API : 2025-01-17 → 2025-01-18
#  600 enregistrements ajoutés pour 2025-01-17
#  Appel API : 2025-01-18 → 2025-01-19
#  600 enregistrements ajoutés pour 2025-01-18
#  Appel API : 2025-01-19 → 2025-01-20
#  600 enregistrements ajoutés pour 2025-01-19
# 1198   408009.560  2025-07-16T22:00:00+02:00  price-areas
# 1199   396544.700  2025-07-16T23:00:00+02:00  price-areas
#
# [1200 rows x 12 columns]

# %%
df_cons_collect = df_cons_collect.drop(columns=['lastUpdatedTime']) # Drop unnecessary columns

# %%
df_cons_collect
# Out:
#      consumptionGroup country               eic                    endTime  \
# 0               cabin      NO  10YNO-1--------2  2025-07-15T01:00:00+02:00
# 1               cabin      NO  10YNO-1--------2  2025-07-15T02:00:00+02:00
# 2               cabin      NO  10YNO-1--------2  2025-07-15T03:00:00+02:00
# 3               cabin      NO  10YNO-1--------2  2025-07-15T04:00:00+02:00
# 4               cabin      NO  10YNO-1--------2  2025-07-15T05:00:00+02:00
# ...               ...     ...               ...                        ...
# 1195         tertiary      NO  10Y1001A1001A48H  2025-07-16T20:00:00+02:00
# 1196         tertiary      NO  10Y1001A1001A48H  2025-07-16T21:00:00+02:00
# 1197         tertiary      NO  10Y1001A1001A48H  2025-07-16T22:00:00+02:00
# 1198         tertiary      NO  10Y1001A1001A48H  2025-07-16T23:00:00+02:00
# 1199         tertiary      NO  10Y1001A1001A48H  2025-07-17T00:00:00+02:00
#
#        id  meteringPointCount name priceArea  quantityKwh  \
# 0     NO1              109677  NO1       NO1    44426.387
# 1     NO1              109677  NO1       NO1    41092.910
# 2     NO1              109677  NO1       NO1    38442.156
# 3     NO1              109677  NO1       NO1    36801.008
# 4     NO1              109677  NO1       NO1    35028.797
# ...   ...                 ...  ...       ...          ...
# 1195  NO5               29205  NO5       NO5   437107.250
# 1196  NO5               29205  NO5       NO5   430533.030
# 1197  NO5               29205  NO5       NO5   422526.120
# 1198  NO5               29205  NO5       NO5   408009.560
# 1199  NO5               29205  NO5       NO5   396544.700
#
#                       startTime         type
# 0     2025-07-15T00:00:00+02:00  price-areas
# 1     2025-07-15T01:00:00+02:00  price-areas
# 2     2025-07-15T02:00:00+02:00  price-areas
# 3     2025-07-15T03:00:00+02:00  price-areas
# 4     2025-07-15T04:00:00+02:00  price-areas
# ...                         ...          ...
# 1195  2025-07-16T19:00:00+02:00  price-areas
# 1196  2025-07-16T20:00:00+02:00  price-areas
# 1197  2025-07-16T21:00:00+02:00  price-areas
# 1198  2025-07-16T22:00:00+02:00  price-areas
# 1199  2025-07-16T23:00:00+02:00  price-areas
#
# [1200 rows x 11 columns]

# %%
df_cons_collect['consumptionGroup'].unique()     # Get unique consumption groups from the DataFrame
# Out:
# array(['cabin', 'household', 'primary', 'secondary', 'tertiary'],
#       dtype=object)

# %%
df_cons_collect.to_csv("consumption_price_areas.csv", index=False) # Save the result to a CSV file

# %% [markdown]
# ### Vue d'ensemble
#
# Ce code effectue un test initial de l'API Elhub pour vérifier la connectivité et comprendre la structure des données avant d'implémenter l'automatisation complète.
#
# ### Endpoint utilisé
#
# URL : https://api.elhub.no/energy-data/v0/municipalities
#
# Scope : Données au niveau des municipalités
#
# ### Paramètres de requête
#
# dataset : PRODUCTION_PER_METERING_POINT_TYPE_MUNICIPALITY_HOUR
#
# Type de données : Production par type de point de mesure par municipalité et par heure
#
# ### Objectifs du test
#
# Vérification de connectivité : S'assurer que l'API répond correctement
#
# Exploration des données : Comprendre la structure JSON retournée
#
# Validation des paramètres : Tester le format des dates et paramètres
#
# Gestion d'erreurs : Identifier les codes d'erreur possibles
#
# ### Résultats attendus
#
# #### Succès (status_code = 200)
#
# Affichage de la réponse JSON complète
#
# #### Échec (status_code ≠ 200)
#
# Codes d'erreur possibles :
#
# 401 : Authentification requise
#
# 403 : Accès interdit
#
# 404 : Endpoint non trouvé
#
# 422 : Paramètres invalides
#
# 429 : Trop de requêtes (rate limiting)

# %%
headers = {
    
}

response = requests.get('https://api.elhub.no/energy-data/v0/municipalities?dataset=PRODUCTION_PER_METERING_POINT_TYPE_MUNICIPALITY_HOUR&startDate=2023-05-03T20:00:00%2B02:00&endDate=2023-05-04T00:00:00%2B02:00', headers=headers)
if response.status_code == 200:
    print(response.json())
else:
    print('Error:', response.status_code)
# Out:
# {'meta': {'created': '2025-05-19T15:16:27+02:00', 'lastUpdated': '2025-03-29T01:45:22+01:00'}, 'links': {'self': 'https://api.elhub.no/energy-data/v0/municipalities?dataset=PRODUCTION_PER_METERING_POINT_TYPE_MUNICIPALITY_HOUR&endDate=2023-05-04T00%3A00%3A00%2B02%3A00&startDate=2023-05-03T20%3A00%3A00%2B02%3A00'}, 'data': [{'type': 'municipality', 'id': '*', 'attributes': {'municipalityNumber': '*', 'name': '*', 'nameNo': '*', 'productionPerMeteringPointTypeMunicipalityHour': []}}, {'type': 'municipality', 'id': '0000', 'attributes': {'municipalityNumber': '0000', 'name': 'Ukjent tilhørighet', 'nameNo': 'Ukjent tilhørighet', 'productionPerMeteringPointTypeMunicipalityHour': []}}, {'type': 'municipality', 'id': '0301', 'attributes': {'municipalityNumber': '0301', 'name': 'Oslo', 'nameNo': 'Oslo', 'productionPerMeteringPointTypeMunicipalityHour': [{'startTime': '2023-05-03T20:00:00+02:00', 'endTime': '2023-05-03T21:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 6.609, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}, {'startTime': '2023-05-03T21:00:00+02:00', 'endTime': '2023-05-03T22:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 3.814, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}, {'startTime': '2023-05-03T22:00:00+02:00', 'endTime': '2023-05-03T23:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 2.672, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}, {'startTime': '2023-05-03T23:00:00+02:00', 'endTime': '2023-05-04T00:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 4.417, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}]}}, {'type': 'municipality', 'id': '1101', 'attributes': {'municipalityNumber': '1101', 'name': 'Eigersund', 'nameNo': 'Eigersund', 'productionPerMeteringPointTypeMunicipalityHour': [{'startTime': '2023-05-03T20:00:00+02:00', 'endTime': '2023-05-03T21:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 13.634, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}, {'startTime': '2023-05-03T21:00:00+02:00', 'endTime': '2023-05-03T22:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 0.09, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}, {'startTime': '2023-05-03T22:00:00+02:00', 'endTime': '2023-05-03T23:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 0.03, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}, {'startTime': '2023-05-03T23:00:00+02:00', 'endTime': '2023-05-04T00:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 0.01, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}]}}, {'type': 'municipality', 'id': '1103', 'attributes': {'municipalityNumber': '1103', 'name': 'Stavanger', 'nameNo': 'Stavanger', 'productionPerMeteringPointTypeMunicipalityHour': [{'startTime': '2023-05-03T20:00:00+02:00', 'endTime': '2023-05-03T21:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 39.225, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}, {'startTime': '2023-05-03T21:00:00+02:00', 'endTime': '2023-05-03T22:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 0.874, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}, {'startTime': '2023-05-03T22:00:00+02:00', 'endTime': '2023-05-03T23:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 0.111, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}, {'startTime': '2023-05-03T23:00:00+02:00', 'endTime': '2023-05-04T00:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 0.028, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}]}}, {'type': 'municipality', 'id': '1106', 'attributes': {'municipalityNumber': '1106', 'name': 'Haugesund', 'nameNo': 'Haugesund', 'productionPerMeteringPointTypeMunicipalityHour': [{'startTime': '2023-05-03T20:00:00+02:00', 'endTime': '2023-05-03T21:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 18.927, 'lastUpdatedTime': '2025-03-29T01:45:22+01:00'}, {'startTime': '2023-05-03T21:00:00+02:00', 'endTime': '2023-05-03T22:00:00+02:00', 'meteringPointTypeCode': 'E19', 'quantityKwh': 0.037, 'lastUpdatedTime': '2025-03-29T01:45:22+01 ...

# %% [markdown]
# Metering Point Type
# Codes according to ebIX:
#
# E17 Consumption
# E18 Production
# E19 Combined
# E20 Exchange

# %%
# Constants
dataset = "PRODUCTION_PER_METERING_POINT_TYPE_MUNICIPALITY_HOUR"  # Dataset identifier in the API
base_url = "https://api.elhub.no/energy-data/v0/municipalities"    # Base URL for the API endpoint

# Start and end dates
start_date = datetime(2025, 7, 15)   # Start date for data collection authorized by the API
end_limit = datetime.now()        # Current date and time

# Output CSV file
file_name = "municipalities_production.csv"

# Collections pour stocker toutes les données et détecter les colonnes
all_rows = []
all_fieldnames = set()

# Boucle principale pour traiter chaque jour
current_date = start_date
while current_date < end_limit:
    # Define the date window (1 day per request)
    end_date = current_date + timedelta(days=1)
    
    # Format dates as ISO 8601 (YYYY-MM-DD)
    start_str = current_date.strftime("%Y-%m-%d")
    end_str = end_date.strftime("%Y-%m-%d")
    
    # Construct the API URL
    url = (
        f"{base_url}?dataset={dataset}"
        f"&startDate={start_str}"
        f"&endDate={end_str}"
    )
    
    print(f"API call: {start_str} → {end_str}")    # Print the API call being made
    
    try:   # Make the API request in a try-except block to handle potential errors
        response = requests.get(url)      # Send GET request to the API
        
        # Check HTTP response
        if response.status_code == 200:    # Check if the request was successful (200 means OK)
            json_full = response.json()                # Parse the JSON response from the API
            data = json_full.get("data", [])          # Extract the "data" field from the JSON response, defaulting to an empty list if not present
            
            # Loop over each municipality record
            for item in data:
                if not isinstance(item, dict):
                    continue
                
                # Structure de base avec les champs de niveau supérieur
                base_row = {
                    "type": item.get("type"),
                    "id": item.get("id")
                }
                
                attr = item.get("attributes", {})
                
                # Ajouter automatiquement tous les attributs (sauf les données imbriquées)
                for attr_key, attr_value in attr.items():  # Loop through each attribute in the attributes dictionary
                    if attr_key != "productionPerMeteringPointTypeMunicipalityHour":      # Skip the nested production data 
                        base_row[attr_key] = attr_value  # Add each attribute to the base row
                
                # Loop over each hourly production record
                for record in attr.get("productionPerMeteringPointTypeMunicipalityHour", []):     # Extract the hourly production data
                    # Créer une ligne complète en combinant les infos de base et les données horaires
                    row = {**base_row}  # Copier les données de base
                    
                    # Ajouter automatiquement toutes les données du record
                    for record_key, record_value in record.items():
                        row[record_key] = record_value
                    
                    # Ajouter toutes les clés trouvées à notre ensemble d'en-têtes
                    all_fieldnames.update(row.keys())
                    all_rows.append(row)
            
            if data: # Print the number of records processed for the current date
                print(f"  {len(data)} municipality records processed for {start_str}")
            else:
                print(f"  No data available for {start_str}")  # Print if no data was found for the current date
                
        else:   # Print error if the API call was not successful
            print(f"API call failed: HTTP {response.status_code}")
            print(f"Response: {response.text}")
            
    except Exception as e: # Handle any exceptions that occur during the API call
        print(f"API error: {e}")    # Print any exceptions that occur during the API call
    
    # Move to the next day
    current_date = end_date   # Increment the current date by one day to process the next date
    time.sleep(1)  # Prevent rate limiting (429 errors)

# Écrire toutes les données dans le fichier CSV avec les en-têtes détectées automatiquement
if all_rows:   # Check if there are any rows to write
    with open(file_name, mode="w", newline="", encoding="utf-8") as file:  # Open the file for writing
        # Trier les en-têtes pour avoir un ordre cohérent
        sorted_fieldnames = sorted(all_fieldnames)
        writer = csv.DictWriter(file, fieldnames=sorted_fieldnames)   
        writer.writeheader()
        writer.writerows(all_rows)
    
    print(f"\nAll data saved in CSV file: {file_name}")
    print(f"Automatically detected columns: {sorted_fieldnames}")
    print(f"Total rows written: {len(all_rows)}")
else:
    print("No data found in the specified date range")
# Out:
# API call: 2021-01-01 → 2021-01-02
#   48 records written for 2021-01-01
# API call: 2021-01-02 → 2021-01-03
#   456 records written for 2021-01-02
# API call: 2021-01-03 → 2021-01-04
#   456 records written for 2021-01-03
# API call: 2021-01-04 → 2021-01-05
#   456 records written for 2021-01-04
# API call: 2021-01-05 → 2021-01-06
#   456 records written for 2021-01-05
# API call: 2021-01-06 → 2021-01-07
#   432 records written for 2021-01-06
# API call: 2021-01-07 → 2021-01-08
#   432 records written for 2021-01-07
# API call: 2021-01-08 → 2021-01-09
#   432 records written for 2021-01-08
# API call: 2021-01-09 → 2021-01-10
#   432 records written for 2021-01-09
# API call: 2021-01-10 → 2021-01-11
#   432 records written for 2021-01-10
# API call: 2021-01-11 → 2021-01-12
#   432 records written for 2021-01-11
# API call: 2021-01-12 → 2021-01-13
#   432 records written for 2021-01-12
# API call: 2021-01-13 → 2021-01-14
#   432 records written for 2021-01-13
# API call: 2021-01-14 → 2021-01-15
#   432 records written for 2021-01-14
# API call: 2021-01-15 → 2021-01-16
#   432 records written for 2021-01-15
# API call: 2021-01-16 → 2021-01-17
#   432 records written for 2021-01-16
# API call: 2021-01-17 → 2021-01-18
#   432 records written for 2021-01-17
# API call: 2021-01-18 → 2021-01-19
#   432 records written for 2021-01-18
# API call: 2021-01-19 → 2021-01-20
#   432 records written for 2021-01-19
# API call: 2021-01-20 → 2021-01-21
#   432 records written for 2021-01-20
# API call: 2021-01-21 → 2021-01-22
#   432 records written for 2021-01-21
# API call: 2021-01-22 → 2021-01-23
#   456 records written for 2021-01-22
# API call: 2021-01-23 → 2021-01-24
#   456 records written for 2021-01-23
# API call: 2021-01-24 → 2021-01-25
#   456 records written for 2021-01-24
# API call: 2021-01-25 → 2021-01-26
#   456 records written for 2021-01-25
# API call: 2021-01-26 → 2021-01-27
#   456 records written for 2021-01-26
# API call: 2021-01-27 → 2021-01-28
#   456 records written for 2021-01-27
# API call: 2021-01-28 → 2021-01-29
#   456 records written for 2021-01-28
# API call: 2021-01-29 → 2021-01-30
#   3840 records written for 2021-01-29
# API call: 2021-01-30 → 2021-01-31
#   3840 records written for 2021-01-30
# API call: 2021-01-31 → 2021-02-01
#   3840 records written for 2021-01-31
# API call: 2021-02-01 → 2021-02-02
#   3840 records written for 2021-02-01
# API call: 2021-02-02 → 2021-02-03
#   3840 records written for 2021-02-02
# API call: 2021-02-03 → 2021-02-04
#   3840 records written for 2021-02-03
# API call: 2021-02-04 → 2021-02-05
#   3840 records written for 2021-02-04
# API call: 2021-02-05 → 2021-02-06
#   3840 records written for 2021-02-05
# API call: 2021-02-06 → 2021-02-07
#   3840 records written for 2021-02-06
# API call: 2021-02-07 → 2021-02-08
#   3840 records written for 2021-02-07
# API call: 2021-02-08 → 2021-02-09
#   3840 records written for 2021-02-08
# API call: 2021-02-09 → 2021-02-10
#   3840 records written for 2021-02-09
# API call: 2021-02-10 → 2021-02-11
#   3840 records written for 2021-02-10
# API call: 2021-02-11 → 2021-02-12
#   3840 records written for 2021-02-11
# API call: 2021-02-12 → 2021-02-13
#   3840 records written for 2021-02-12
# API call: 2021-02-13 → 2021-02-14
#   3840 records written for 2021-02-13
# API call: 2021-02-14 → 2021-02-15
#   3840 records written for 2021-02-14
# API call: 2021-02-15 → 2021-02-16
#   3840 records written for 2021-02-15
# API call: 2021-02-16 → 2021-02-17
#   3840 records written for 2021-02-16
# API call: 2021-02-17 → 2021-02-18
#   3840 records written for 2021-02-17
# API call: 2021-02-18 → 2021-02-19
#   3840 records written for 2021-02-18
# API call: 2021-02-19 → 2021-02-20
#   3840 records written for 2021-02-19
# API call: 2021-02-20 → 2021-02-21
#   3840 records written for 2021-02-20
# API call: 2021-02-21 → 2021-02-22
#   3840 records written for 2021-02-21
# API call: 2021-02-22 → 2021-02-23
#   3840 records written for 2021-02-22
# API call: 2021-02-23 → 2021-02-24
#   3840 records written for 2021-02-23
# API call: 2021-02-24 → 2021-02-25
#   3840 records written for 2021-02-24
# API call: 2021-02-25 → 2021-02-26
#   3840 records written for 2021-02-25
# API call: 2021-02-26 → 2021-02-27
#   3840 records written for 2021-02-26
# API call: 2021-02-27 → 2021-02-28
#   3840 records written for 2021-02-27
# API call: 2021-02-28 → 2021-03-01
#   3840 records written for 2021-02-28
# API call: 2021-03-01 → 2021-03-02
#   3840 records written for 2021-03-01
# API call: 2021-03-02 → 2021-03-03
#   3840 records written for 2021-03-02
# API call: 2021-03-03 → 2021-03-04
#   3840 records written for 2021-03-03
# API call: 2021-03-04 → 2021-03-05
#   3840 records written for 2021-03-04
# API call: 2021-03-05 → 2021-03-06
#   3840 records written for 2021-03-05
# API call: 2021-03-06 → 2021-03-07
#   3840 records written for 2021-03-06
# API call: 2021-03-07 → 2021-03-08
#   3840 records written for 2021-03-07
# API call: 2021-03-08 → 2021-03-09
#   3840 records written for 2021-03-08
# API call: 2021-03-09 → 2021-03-10
#   3840 records written for 2021-03-09
# API call: 2021-03-10 → 2021-03-11
#   3840 records written for 2021-03-10
# API call: 2021-03-11 → 2021-03-12
#   3840 records written for 2021-03-11
# API call: 2021-03-12 → 2021-03-13
#   3840 records written for 2021-03-12
# API call: 2021-03-13 → 2021-03-14
#   3840 records written for 2021-03-13
# API call: 2021-03-14 → 2021-03-15
#   3840 records written for 2021-03-14
# API call: 2021-07-18 → 2021-07-19
#   4248 records written for 2021-07-18
# API call: 2021-07-19 → 2021-07-20
#   4248 records written for 2021-07-19
# API call: 2021-07-20 → 2021-07-21
#   4248 records written for 2021-07-20
# API call: 2021-07-21 → 2021-07-22
#   4248 records written for 2021-07-21
# API call: 2021-07-22 → 2021-07-23
#   4248 records written for 2021-07-22
# API call: 2021-07-23 → 2021-07-24
#   4248 records written for 2021-07-23
# API call: 2021-07-24 → 2021-07-25
#   4248 records written for 2021-07-24
# API call: 2021-07-25 → 2021-07-26
#   4248 records written for 2021-07-25
# API call: 2021-07-26 → 2021-07-27
#   4248 records written for 2021-07-26
# API call: 2021-07-27 → 2021-07-28
#   4248 records written for 2021-07-27
# API call: 2021-07-28 → 2021-07-29
#   4248 records written for 2021-07-28
# API call: 2021-07-29 → 2021-07-30
#   4248 records written for 2021-07-29
# API call: 2021-07-30 → 2021-07-31
#   4248 records written for 2021-07-30
# API call: 2021-07-31 → 2021-08-01
#   4248 records written for 2021-07-31
# API call: 2021-08-01 → 2021-08-02
#   4248 records written for 2021-08-01
# API call: 2021-08-02 → 2021-08-03
#   4248 records written for 2021-08-02
# API call: 2021-08-03 → 2021-08-04
#   4248 records written for 2021-08-03
# API call: 2021-08-04 → 2021-08-05
#   4272 records written for 2021-08-04
# API call: 2021-08-05 → 2021-08-06
#   4272 records written for 2021-08-05
# API call: 2021-08-06 → 2021-08-07
#   4272 records written for 2021-08-06
# API call: 2021-08-07 → 2021-08-08
#   4272 records written for 2021-08-07
# API call: 2021-08-08 → 2021-08-09
#   4272 records written for 2021-08-08
# API call: 2021-08-09 → 2021-08-10
#   4272 records written for 2021-08-09
# API call: 2021-08-10 → 2021-08-11
#   4272 records written for 2021-08-10
# API call: 2021-08-11 → 2021-08-12
#   4272 records written for 2021-08-11
# API call: 2021-08-12 → 2021-08-13
#   4272 records written for 2021-08-12
# API call: 2021-08-13 → 2021-08-14
#   4272 records written for 2021-08-13
# API call: 2021-08-14 → 2021-08-15
#   4272 records written for 2021-08-14
# API call: 2021-08-15 → 2021-08-16
#   4272 records written for 2021-08-15
# API call: 2021-08-16 → 2021-08-17
#   4272 records written for 2021-08-16
# API call: 2021-08-17 → 2021-08-18
#   4272 records written for 2021-08-17
# API call: 2021-08-18 → 2021-08-19
#   4272 records written for 2021-08-18
# API call: 2021-08-19 → 2021-08-20
#   4272 records written for 2021-08-19
# API call: 2021-08-20 → 2021-08-21
#   4272 records written for 2021-08-20
# API call: 2021-08-21 → 2021-08-22
#   4272 records written for 2021-08-21
# API call: 2021-08-22 → 2021-08-23
#   4272 records written for 2021-08-22
# API call: 2021-08-23 → 2021-08-24
#   4272 records written for 2021-08-23
# API call: 2021-08-24 → 2021-08-25
#   4296 records written for 2021-08-24
# API call: 2021-08-25 → 2021-08-26
#   4296 records written for 2021-08-25
# API call: 2021-08-26 → 2021-08-27
#   4296 records written for 2021-08-26
# API call: 2021-08-27 → 2021-08-28
#   4296 records written for 2021-08-27
# API call: 2021-08-28 → 2021-08-29
#   4296 records written for 2021-08-28
# API call: 2021-08-29 → 2021-08-30
#   4296 records written for 2021-08-29
# API call: 2021-08-30 → 2021-08-31
#   4320 records written for 2021-08-30
# API call: 2021-08-31 → 2021-09-01
#   4320 records written for 2021-08-31
# API call: 2021-09-01 → 2021-09-02
#   4344 records written for 2021-09-01
# API call: 2021-09-02 → 2021-09-03
#   4368 records written for 2021-09-02
# API call: 2021-09-03 → 2021-09-04
#   4368 records written for 2021-09-03
# API call: 2021-09-04 → 2021-09-05
#   4368 records written for 2021-09-04
# API call: 2021-09-05 → 2021-09-06
#   4368 records written for 2021-09-05
# API call: 2021-09-06 → 2021-09-07
#   4392 records written for 2021-09-06
# API call: 2021-09-07 → 2021-09-08
#   4392 records written for 2021-09-07
# API call: 2021-09-08 → 2021-09-09
#   4392 records written for 2021-09-08
# API call: 2021-09-09 → 2021-09-10
#   4392 records written for 2021-09-09
# API call: 2021-09-10 → 2021-09-11
#   4392 records written for 2021-09-10
# API call: 2021-09-11 → 2021-09-12
#   4392 records written for 2021-09-11
# API call: 2021-09-12 → 2021-09-13
#   4392 records written for 2021-09-12
# API call: 2021-09-13 → 2021-09-14
#   4392 records written for 2021-09-13
# API call: 2021-09-14 → 2021-09-15
#   4392 records written for 2021-09-14
# API call: 2021-09-15 → 2021-09-16
#   4392 records written for 2021-09-15
# API call: 2021-09-16 → 2021-09-17
#   4392 records written for 2021-09-16
# API call: 2021-09-17 → 2021-09-18
#   4392 records written for 2021-09-17
# API call: 2021-09-18 → 2021-09-19
#   4392 records written for 2021-09-18
# API call: 2021-09-19 → 2021-09-20
#   4392 records written for 2021-09-19
# API call: 2021-09-20 → 2021-09-21
#   4392 records written for 2021-09-20
# API call: 2021-09-21 → 2021-09-22
#   4392 records written for 2021-09-21
# API call: 2021-09-22 → 2021-09-23
#   4392 records written for 2021-09-22
# API call: 2021-09-23 → 2021-09-24
#   4392 records written for 2021-09-23
# API call: 2021-09-24 → 2021-09-25
#   4392 records written for 2021-09-24
# API call: 2021-09-25 → 2021-09-26
#   4392 records written for 2021-09-25
# API call: 2021-09-26 → 2021-09-27
#   4392 records written for 2021-09-26
# API call: 2021-09-27 → 2021-09-28
#   4392 records written for 2021-09-27
# API call: 2021-09-28 → 2021-09-29
#   4392 records written for 2021-09-28
# API call: 2021-09-29 → 2021-09-30
#   4392 records written for 2021-09-29
# API call: 2021-09-30 → 2021-10-01
#   4392 records written for 2021-09-30
# API call: 2021-10-01 → 2021-10-02
#   4392 records written for 2021-10-01
# API call: 2021-10-02 → 2021-10-03
#   4416 records written for 2021-10-02
# API call: 2021-10-03 → 2021-10-04
#   4416 records written for 2021-10-03
# API call: 2021-10-04 → 2021-10-05
#   4416 records written for 2021-10-04
# API call: 2021-10-05 → 2021-10-06
#   4416 records written for 2021-10-05
# API call: 2021-10-06 → 2021-10-07
#   4416 records written for 2021-10-06
# API call: 2021-10-07 → 2021-10-08
#   4440 records written for 2021-10-07
# API call: 2021-10-08 → 2021-10-09
#   4440 records written for 2021-10-08
# API call: 2021-10-09 → 2021-10-10
#   4440 records written for 2021-10-09
# API call: 2021-10-10 → 2021-10-11
#   4440 records written for 2021-10-10
# API call: 2021-10-11 → 2021-10-12
#   4440 records written for 2021-10-11
# API call: 2021-10-12 → 2021-10-13
#   4440 records written for 2021-10-12
# API call: 2021-10-13 → 2021-10-14
#   4440 records written for 2021-10-13
# API call: 2021-10-14 → 2021-10-15
#   4440 records written for 2021-10-14
# API call: 2021-10-15 → 2021-10-16
#   4440 records written for 2021-10-15
# API call: 2021-10-16 → 2021-10-17
#   4440 records written for 2021-10-16
# API call: 2021-10-17 → 2021-10-18
#   4440 records written for 2021-10-17
# API call: 2021-10-18 → 2021-10-19
#   4440 records written for 2021-10-18
# API call: 2021-10-19 → 2021-10-20
#   4440 records written for 2021-10-19
# API call: 2021-10-20 → 2021-10-21
#   4440 records written for 2021-10-20
# API call: 2021-10-21 → 2021-10-22
#   4440 records written for 2021-10-21
# API call: 2021-10-22 → 2021-10-23
#   4440 records written for 2021-10-22
# API call: 2021-10-23 → 2021-10-24
#   4440 records written for 2021-10-23
# API call: 2021-10-24 → 2021-10-25
#   4440 records written for 2021-10-24
# API call: 2021-10-25 → 2021-10-26
#   4440 records written for 2021-10-25
# API call: 2021-10-26 → 2021-10-27
#   4416 records written for 2021-10-26
# API call: 2021-10-27 → 2021-10-28
#   4392 records written for 2021-10-27
# API call: 2021-10-28 → 2021-10-29
#   4392 records written for 2021-10-28
# API call: 2021-10-29 → 2021-10-30
#   4392 records written for 2021-10-29
# API call: 2021-10-30 → 2021-10-31
#   4392 records written for 2021-10-30
# API call: 2021-10-31 → 2021-11-01
#   4575 records written for 2021-10-31
# API call: 2021-11-01 → 2021-11-02
#   4440 records written for 2021-11-01
# API call: 2021-11-02 → 2021-11-03
#   4440 records written for 2021-11-02
# API call: 2021-11-03 → 2021-11-04
#   4440 records written for 2021-11-03
# API call: 2021-11-04 → 2021-11-05
#   4440 records written for 2021-11-04
# API call: 2021-11-05 → 2021-11-06
#   4440 records written for 2021-11-05
# API call: 2021-11-06 → 2021-11-07
#   4440 records written for 2021-11-06
# API call: 2021-11-07 → 2021-11-08
#   4440 records written for 2021-11-07
# API call: 2021-11-08 → 2021-11-09
#   4440 records written for 2021-11-08
# API call: 2021-11-09 → 2021-11-10
#   4440 records written for 2021-11-09
# API call: 2021-11-10 → 2021-11-11
#   4440 records written for 2021-11-10
# API call: 2021-11-11 → 2021-11-12
#   4440 records written for 2021-11-11
# API call: 2021-11-12 → 2021-11-13
#   4440 records written for 2021-11-12
# API call: 2021-11-13 → 2021-11-14
#   4440 records written for 2021-11-13
# API call: 2021-11-14 → 2021-11-15
#   4440 records written for 2021-11-14
# API call: 2021-11-15 → 2021-11-16
#   4440 records written for 2021-11-15
# API call: 2021-11-16 → 2021-11-17
#   4440 records written for 2021-11-16
# API call: 2021-11-17 → 2021-11-18
#   4440 records written for 2021-11-17
# API call: 2021-11-18 → 2021-11-19
#   4440 records written for 2021-11-18
# API call: 2021-11-19 → 2021-11-20
#   4440 records written for 2021-11-19
# API call: 2021-11-20 → 2021-11-21
#   4440 records written for 2021-11-20
# API call: 2021-11-21 → 2021-11-22
#   4440 records written for 2021-11-21
# API call: 2021-11-22 → 2021-11-23
#   4440 records written for 2021-11-22
# API call: 2021-11-23 → 2021-11-24
#   4464 records written for 2021-11-23
# API call: 2021-11-24 → 2021-11-25
#   4464 records written for 2021-11-24
# API call: 2021-11-25 → 2021-11-26
#   4464 records written for 2021-11-25
# API call: 2021-11-26 → 2021-11-27
#   4464 records written for 2021-11-26
# API call: 2021-11-27 → 2021-11-28
#   4464 records written for 2021-11-27
# API call: 2021-11-28 → 2021-11-29
#   4464 records written for 2021-11-28
# API call: 2021-11-29 → 2021-11-30
#   4464 records written for 2021-11-29
# API call: 2021-11-30 → 2021-12-01
#   4464 records written for 2021-11-30
# API call: 2021-12-01 → 2021-12-02
#   4536 records written for 2021-12-01
# API call: 2021-12-02 → 2021-12-03
#   4536 records written for 2021-12-02
# API call: 2021-12-03 → 2021-12-04
#   4536 records written for 2021-12-03
# API call: 2021-12-04 → 2021-12-05
#   4536 records written for 2021-12-04
# API call: 2021-12-05 → 2021-12-06
#   4536 records written for 2021-12-05
# API call: 2021-12-06 → 2021-12-07
#   4536 records written for 2021-12-06
# API call: 2021-12-07 → 2021-12-08
#   4536 records written for 2021-12-07
# API call: 2021-12-08 → 2021-12-09
#   4536 records written for 2021-12-08
# API call: 2021-12-09 → 2021-12-10
#   4536 records written for 2021-12-09
# API call: 2021-12-10 → 2021-12-11
#   4536 records written for 2021-12-10
# API call: 2021-12-11 → 2021-12-12
#   4536 records written for 2021-12-11
# API call: 2021-12-12 → 2021-12-13
#   4536 records written for 2021-12-12
# API call: 2021-12-13 → 2021-12-14
#   4536 records written for 2021-12-13
# API call: 2021-12-14 → 2021-12-15
#   4536 records written for 2021-12-14
# API call: 2021-12-15 → 2021-12-16
#   4536 records written for 2021-12-15
# API call: 2021-12-16 → 2021-12-17
#   4560 records written for 2021-12-16
# API call: 2021-12-17 → 2021-12-18
#   4560 records written for 2021-12-17
# API call: 2021-12-18 → 2021-12-19
#   4560 records written for 2021-12-18
# API call: 2021-12-19 → 2021-12-20
#   4560 records written for 2021-12-19
# API call: 2021-12-20 → 2021-12-21
#   4560 records written for 2021-12-20
# API call: 2021-12-21 → 2021-12-22
#   4560 records written for 2021-12-21
# API call: 2021-12-22 → 2021-12-23
#   4560 records written for 2021-12-22
# API call: 2021-12-23 → 2021-12-24
#   4560 records written for 2021-12-23
# API call: 2021-12-24 → 2021-12-25
#   4560 records written for 2021-12-24
# API call: 2021-12-25 → 2021-12-26
#   4560 records written for 2021-12-25
# API call: 2021-12-26 → 2021-12-27
#   4560 records written for 2021-12-26
# API call: 2021-12-27 → 2021-12-28
#   4560 records written for 2021-12-27
# API call: 2021-12-28 → 2021-12-29
#   4560 records written for 2021-12-28
# API call: 2021-12-29 → 2021-12-30
#   4560 records written for 2021-12-29
# API call: 2021-12-30 → 2021-12-31
#   4560 records written for 2021-12-30
# API call: 2021-12-31 → 2022-01-01
#   4560 records written for 2021-12-31
# API call: 2022-01-01 → 2022-01-02
#   4584 records written for 2022-01-01
# API call: 2022-01-02 → 2022-01-03
#   4584 records written for 2022-01-02
# API call: 2022-01-03 → 2022-01-04
#   4608 records written for 2022-01-03
# API call: 2022-01-04 → 2022-01-05
#   4608 records written for 2022-01-04
# API call: 2022-01-05 → 2022-01-06
#   4608 records written for 2022-01-05
# API call: 2022-01-06 → 2022-01-07
#   4656 records written for 2022-01-06
# API call: 2022-01-07 → 2022-01-08
#   4656 records written for 2022-01-07
# API call: 2022-01-08 → 2022-01-09
#   4656 records written for 2022-01-08
# API call: 2022-01-09 → 2022-01-10
#   4656 records written for 2022-01-09
# API call: 2022-01-10 → 2022-01-11
#   4656 records written for 2022-01-10
# API call: 2022-01-11 → 2022-01-12
#   4656 records written for 2022-01-11
# API call: 2022-01-12 → 2022-01-13
#   4656 records written for 2022-01-12
# API call: 2022-01-13 → 2022-01-14
#   4656 records written for 2022-01-13
# API call: 2022-01-14 → 2022-01-15
#   4656 records written for 2022-01-14
# API call: 2022-01-15 → 2022-01-16
#   4656 records written for 2022-01-15
# API call: 2022-01-16 → 2022-01-17
#   4656 records written for 2022-01-16
# API call: 2022-01-17 → 2022-01-18
#   4656 records written for 2022-01-17
# API call: 2022-01-18 → 2022-01-19
#   4656 records written for 2022-01-18
# API call: 2022-01-19 → 2022-01-20
#   4656 records written for 2022-01-19
# API call: 2022-01-20 → 2022-01-21
#   4656 records written for 2022-01-20
# API call: 2022-01-21 → 2022-01-22
#   4656 records written for 2022-01-21
# API call: 2022-01-22 → 2022-01-23
#   4656 records written for 2022-01-22
# API call: 2022-01-23 → 2022-01-24
#   4656 records written for 2022-01-23
# API call: 2022-01-24 → 2022-01-25
#   4656 records written for 2022-01-24
# API call: 2022-01-25 → 2022-01-26
#   4656 records written for 2022-01-25
# API call: 2022-01-26 → 2022-01-27
#   4656 records written for 2022-01-26
# API call: 2022-01-27 → 2022-01-28
#   4656 records written for 2022-01-27
# API call: 2022-01-28 → 2022-01-29
#   4656 records written for 2022-01-28
# API call: 2022-01-29 → 2022-01-30
#   4656 records written for 2022-01-29
# API call: 2022-01-30 → 2022-01-31
#   4656 records written for 2022-01-30
# API call: 2022-01-31 → 2022-02-01
#   4656 records written for 2022-01-31
# API call: 2022-02-01 → 2022-02-02
#   4656 records written for 2022-02-01
# API call: 2022-02-02 → 2022-02-03
#   4656 records written for 2022-02-02
# API call: 2022-02-03 → 2022-02-04
#   4656 records written for 2022-02-03
# API call: 2022-02-04 → 2022-02-05
#   4656 records written for 2022-02-04
# API call: 2022-02-05 → 2022-02-06
#   4656 records written for 2022-02-05
# API call: 2022-02-06 → 2022-02-07
#   4656 records written for 2022-02-06
# API call: 2022-02-07 → 2022-02-08
#   4656 records written for 2022-02-07
# API call: 2022-02-08 → 2022-02-09
#   4656 records written for 2022-02-08
# API call: 2022-02-09 → 2022-02-10
#   4656 records written for 2022-02-09
# API call: 2022-02-10 → 2022-02-11
#   4656 records written for 2022-02-10
# API call: 2022-02-11 → 2022-02-12
# API call: 2022-03-25 → 2022-03-26
#   4824 records written for 2022-03-25
# API call: 2022-03-26 → 2022-03-27
#   4824 records written for 2022-03-26
# API call: 2022-03-27 → 2022-03-28
#   4623 records written for 2022-03-27
# API call: 2022-03-28 → 2022-03-29
#   4824 records written for 2022-03-28
# API call: 2022-03-29 → 2022-03-30
#   4824 records written for 2022-03-29
# API call: 2022-03-30 → 2022-03-31
#   4800 records written for 2022-03-30
# API call: 2022-03-31 → 2022-04-01
#   4800 records written for 2022-03-31
# API call: 2022-04-01 → 2022-04-02
#   4800 records written for 2022-04-01
# API call: 2022-04-02 → 2022-04-03
#   4800 records written for 2022-04-02
# API call: 2022-04-03 → 2022-04-04
#   4800 records written for 2022-04-03
# API call: 2022-04-04 → 2022-04-05
#   4800 records written for 2022-04-04
# API call: 2022-04-05 → 2022-04-06
#   4800 records written for 2022-04-05
# API call: 2022-04-06 → 2022-04-07
#   4800 records written for 2022-04-06
# API call: 2022-04-07 → 2022-04-08
#   4800 records written for 2022-04-07
# API call: 2022-04-08 → 2022-04-09
#   4800 records written for 2022-04-08
# API call: 2022-04-09 → 2022-04-10
#   4800 records written for 2022-04-09
# API call: 2022-04-10 → 2022-04-11
#   4800 records written for 2022-04-10
# API call: 2022-04-11 → 2022-04-12
#   4800 records written for 2022-04-11
# API call: 2022-04-12 → 2022-04-13
#   4800 records written for 2022-04-12
# API call: 2022-04-13 → 2022-04-14
#   4800 records written for 2022-04-13
# API call: 2022-04-14 → 2022-04-15
#   4800 records written for 2022-04-14
# API call: 2022-04-15 → 2022-04-16
#   4800 records written for 2022-04-15
# API call: 2022-04-16 → 2022-04-17
#   4800 records written for 2022-04-16
# API call: 2022-04-17 → 2022-04-18
#   4800 records written for 2022-04-17
# API call: 2022-04-18 → 2022-04-19
#   4800 records written for 2022-04-18
# API call: 2022-04-19 → 2022-04-20
#   4848 records written for 2022-04-19
# API call: 2022-04-20 → 2022-04-21
#   4848 records written for 2022-04-20
# API call: 2022-04-21 → 2022-04-22
#   5256 records written for 2022-04-21
# API call: 2022-04-22 → 2022-04-23
#   5256 records written for 2022-04-22
# API call: 2022-04-23 → 2022-04-24
#   5256 records written for 2022-04-23
# API call: 2022-04-24 → 2022-04-25
#   5256 records written for 2022-04-24
# API call: 2022-04-25 → 2022-04-26
#   5256 records written for 2022-04-25
# API call: 2022-04-26 → 2022-04-27
#   5256 records written for 2022-04-26
# API call: 2022-04-27 → 2022-04-28
#   5280 records written for 2022-04-27
# API call: 2022-04-28 → 2022-04-29
#   5304 records written for 2022-04-28
# API call: 2022-04-29 → 2022-04-30
#   5304 records written for 2022-04-29
# API call: 2022-04-30 → 2022-05-01
#   5304 records written for 2022-04-30
# API call: 2022-05-01 → 2022-05-02
#   5304 records written for 2022-05-01
# API call: 2022-05-02 → 2022-05-03
#   5304 records written for 2022-05-02
# API call: 2022-05-03 → 2022-05-04
#   5304 records written for 2022-05-03
# API call: 2022-05-04 → 2022-05-05
#   5304 records written for 2022-05-04
# API call: 2022-05-05 → 2022-05-06
#   5328 records written for 2022-05-05
# API call: 2022-05-06 → 2022-05-07
#   5328 records written for 2022-05-06
# API call: 2022-05-07 → 2022-05-08
#   5328 records written for 2022-05-07
# API call: 2022-05-08 → 2022-05-09
#   5328 records written for 2022-05-08
# API call: 2022-05-09 → 2022-05-10
#   5352 records written for 2022-05-09
# API call: 2022-05-10 → 2022-05-11
#   5352 records written for 2022-05-10
# API call: 2022-05-11 → 2022-05-12
#   5352 records written for 2022-05-11
# API call: 2022-05-12 → 2022-05-13
#   5376 records written for 2022-05-12
# API call: 2022-05-13 → 2022-05-14
#   5400 records written for 2022-05-13
# API call: 2022-05-14 → 2022-05-15
#   5400 records written for 2022-05-14
# API call: 2022-05-15 → 2022-05-16
#   5400 records written for 2022-05-15
# API call: 2022-05-16 → 2022-05-17
#   5400 records written for 2022-05-16
# API call: 2022-05-17 → 2022-05-18
#   5400 records written for 2022-05-17
# API call: 2022-05-18 → 2022-05-19
#   5400 records written for 2022-05-18
# API call: 2022-05-19 → 2022-05-20
#   5400 records written for 2022-05-19
# API call: 2022-05-20 → 2022-05-21
#   5400 records written for 2022-05-20
# API call: 2022-05-21 → 2022-05-22
#   5400 records written for 2022-05-21
# API call: 2022-05-22 → 2022-05-23
#   5400 records written for 2022-05-22
# API call: 2022-05-23 → 2022-05-24
#   5400 records written for 2022-05-23
# API call: 2022-05-24 → 2022-05-25
#   5400 records written for 2022-05-24
# API call: 2022-05-25 → 2022-05-26
#   5400 records written for 2022-05-25
# API call: 2022-05-26 → 2022-05-27
#   5400 records written for 2022-05-26
# API call: 2022-05-27 → 2022-05-28
#   5400 records written for 2022-05-27
# API call: 2022-05-28 → 2022-05-29
#   5400 records written for 2022-05-28
# API call: 2022-05-29 → 2022-05-30
#   5400 records written for 2022-05-29
# API call: 2022-05-30 → 2022-05-31
#   5400 records written for 2022-05-30
# API call: 2022-05-31 → 2022-06-01
#   5400 records written for 2022-05-31
# API call: 2022-06-01 → 2022-06-02
#   5424 records written for 2022-06-01
# API call: 2022-06-02 → 2022-06-03
#   5424 records written for 2022-06-02
# API call: 2022-06-03 → 2022-06-04
#   5424 records written for 2022-06-03
# API call: 2022-06-04 → 2022-06-05
#   5424 records written for 2022-06-04
# API call: 2022-06-05 → 2022-06-06
#   5424 records written for 2022-06-05
# API call: 2022-06-06 → 2022-06-07
#   5424 records written for 2022-06-06
# API call: 2022-06-07 → 2022-06-08
#   5424 records written for 2022-06-07
# API call: 2022-06-08 → 2022-06-09
#   5424 records written for 2022-06-08
# API call: 2022-06-09 → 2022-06-10
#   5448 records written for 2022-06-09
# API call: 2022-06-10 → 2022-06-11
#   5448 records written for 2022-06-10
# API call: 2022-06-11 → 2022-06-12
#   5448 records written for 2022-06-11
# API call: 2022-06-12 → 2022-06-13
#   5448 records written for 2022-06-12
# API call: 2022-06-13 → 2022-06-14
#   5448 records written for 2022-06-13
# API call: 2022-06-14 → 2022-06-15
#   5448 records written for 2022-06-14
# API call: 2022-06-15 → 2022-06-16
#   5472 records written for 2022-06-15
# API call: 2025-01-05 → 2025-01-06
#   6552 records written for 2025-01-05
# API call: 2025-01-06 → 2025-01-07
#   6552 records written for 2025-01-06
# API call: 2025-01-07 → 2025-01-08
#   6552 records written for 2025-01-07
# API call: 2025-01-08 → 2025-01-09
#   6552 records written for 2025-01-08
# API call: 2025-01-09 → 2025-01-10
#   6552 records written for 2025-01-09
# API call: 2025-01-10 → 2025-01-11
#   6552 records written for 2025-01-10
# API call: 2025-01-11 → 2025-01-12
#   6552 records written for 2025-01-11
# API call: 2025-01-12 → 2025-01-13
#   6552 records written for 2025-01-12
# API call: 2025-01-13 → 2025-01-14
#   6552 records written for 2025-01-13
# API call: 2025-01-14 → 2025-01-15
#   6552 records written for 2025-01-14
# API call: 2025-01-15 → 2025-01-16
#   6552 records written for 2025-01-15
# API call: 2025-01-16 → 2025-01-17
#   6552 records written for 2025-01-16
# API call: 2025-01-17 → 2025-01-18
#   6552 records written for 2025-01-17
# API call: 2025-01-18 → 2025-01-19
#   6552 records written for 2025-01-18
# API call: 2025-01-19 → 2025-01-20
#   6552 records written for 2025-01-19
# API call: 2025-01-20 → 2025-01-21
#   6552 records written for 2025-01-20
# API call: 2025-01-21 → 2025-01-22
#   6552 records written for 2025-01-21
# API call: 2025-01-22 → 2025-01-23
#   6552 records written for 2025-01-22
# API call: 2025-01-23 → 2025-01-24
#   6552 records written for 2025-01-23
# API call: 2025-01-24 → 2025-01-25
#   6552 records written for 2025-01-24
# API call: 2025-01-25 → 2025-01-26
#   6552 records written for 2025-01-25
# API call: 2025-01-26 → 2025-01-27
#   6552 records written for 2025-01-26
# API call: 2025-01-27 → 2025-01-28
#   6552 records written for 2025-01-27
# API call: 2025-01-28 → 2025-01-29
#   6552 records written for 2025-01-28
# API call: 2025-01-29 → 2025-01-30
#   6552 records written for 2025-01-29
# API call: 2025-01-30 → 2025-01-31
#   6552 records written for 2025-01-30
# API call: 2025-01-31 → 2025-02-01
#   6552 records written for 2025-01-31
# API call: 2025-02-01 → 2025-02-02
#   6552 records written for 2025-02-01
# API call: 2025-02-02 → 2025-02-03
#   6552 records written for 2025-02-02
# API call: 2025-02-03 → 2025-02-04
#   6552 records written for 2025-02-03
# API call: 2025-02-04 → 2025-02-05
#   6552 records written for 2025-02-04
# API call: 2025-02-05 → 2025-02-06
#   6552 records written for 2025-02-05
# API call: 2025-02-06 → 2025-02-07
#   6552 records written for 2025-02-06
# API call: 2025-02-07 → 2025-02-08
#   6552 records written for 2025-02-07
# API call: 2025-02-08 → 2025-02-09
#   6552 records written for 2025-02-08
# API call: 2025-02-09 → 2025-02-10
#   6552 records written for 2025-02-09
# API call: 2025-02-10 → 2025-02-11
#   6552 records written for 2025-02-10
# API call: 2025-02-11 → 2025-02-12
#   6552 records written for 2025-02-11
# API call: 2025-02-12 → 2025-02-13
#   6552 records written for 2025-02-12
# API call: 2025-02-13 → 2025-02-14
#   6552 records written for 2025-02-13
# API call: 2025-02-14 → 2025-02-15
#   6552 records written for 2025-02-14
# API call: 2025-02-15 → 2025-02-16
#   6552 records written for 2025-02-15
# API call: 2025-05-10 → 2025-05-11
#   6552 records written for 2025-05-10
# API call: 2025-05-11 → 2025-05-12
#   6552 records written for 2025-05-11
# API call: 2025-05-12 → 2025-05-13
#   6552 records written for 2025-05-12
# API call: 2025-05-13 → 2025-05-14
#   6552 records written for 2025-05-13
# API call: 2025-05-14 → 2025-05-15
#   6552 records written for 2025-05-14
# API call: 2025-05-15 → 2025-05-16
#   6552 records written for 2025-05-15
# API call: 2025-05-16 → 2025-05-17
#   6552 records written for 2025-05-16
# API call: 2025-05-17 → 2025-05-18
#   6552 records written for 2025-05-17
# API call: 2025-05-18 → 2025-05-19
#   6552 records written for 2025-05-18
# API call: 2025-05-19 → 2025-05-20
#   6552 records written for 2025-05-19
# API call: 2025-05-20 → 2025-05-21
#   6552 records written for 2025-05-20
# API call: 2025-05-21 → 2025-05-22
#   6552 records written for 2025-05-21
# API call: 2025-05-22 → 2025-05-23
#   6552 records written for 2025-05-22
# API call: 2025-05-23 → 2025-05-24
#   6552 records written for 2025-05-23
# API call: 2025-05-24 → 2025-05-25
#   6552 records written for 2025-05-24
# API call: 2025-05-25 → 2025-05-26
#   6552 records written for 2025-05-25
# API call: 2025-05-26 → 2025-05-27
#   6552 records written for 2025-05-26
# API call: 2025-05-27 → 2025-05-28
#   6552 records written for 2025-05-27
# API call: 2025-05-28 → 2025-05-29
#   6552 records written for 2025-05-28
# API call: 2025-05-29 → 2025-05-30
#   6552 records written for 2025-05-29
# API call: 2025-05-30 → 2025-05-31
#   6552 records written for 2025-05-30
# API call: 2025-05-31 → 2025-06-01
#   6552 records written for 2025-05-31
# API call: 2025-06-01 → 2025-06-02
#   No data available for 2025-06-01
# API call: 2025-06-02 → 2025-06-03
#   No data available for 2025-06-02
#
#  All data saved in CSV file: municipalities_production.csv

# %%
df_production=pd.read_csv('municipalities_production.csv')

# %%
df_production
# Out:
#                  type    id  municipalityNumber          name        nameNo  \
# 0        municipality  1103                1103     Stavanger     Stavanger
# 1        municipality  1103                1103     Stavanger     Stavanger
# 2        municipality  1103                1103     Stavanger     Stavanger
# 3        municipality  1103                1103     Stavanger     Stavanger
# 4        municipality  1103                1103     Stavanger     Stavanger
# ...               ...   ...                 ...           ...           ...
# 9028103  municipality  5605                5605  Sør-Varanger  Sør-Varanger
# 9028104  municipality  5605                5605  Sør-Varanger  Sør-Varanger
# 9028105  municipality  5605                5605  Sør-Varanger  Sør-Varanger
# 9028106  municipality  5605                5605  Sør-Varanger  Sør-Varanger
# 9028107  municipality  5605                5605  Sør-Varanger  Sør-Varanger
#
#                          startTime                    endTime  \
# 0        2021-01-01T00:00:00+01:00  2021-01-01T01:00:00+01:00
# 1        2021-01-01T01:00:00+01:00  2021-01-01T02:00:00+01:00
# 2        2021-01-01T02:00:00+01:00  2021-01-01T03:00:00+01:00
# 3        2021-01-01T03:00:00+01:00  2021-01-01T04:00:00+01:00
# 4        2021-01-01T04:00:00+01:00  2021-01-01T05:00:00+01:00
# ...                            ...                        ...
# 9028103  2025-05-31T19:00:00+02:00  2025-05-31T20:00:00+02:00
# 9028104  2025-05-31T20:00:00+02:00  2025-05-31T21:00:00+02:00
# 9028105  2025-05-31T21:00:00+02:00  2025-05-31T22:00:00+02:00
# 9028106  2025-05-31T22:00:00+02:00  2025-05-31T23:00:00+02:00
# 9028107  2025-05-31T23:00:00+02:00  2025-06-01T00:00:00+02:00
#
#         meteringPointTypeCode  quantityKwh            lastUpdatedTime
# 0                         E19        0.000  2025-03-30T11:46:56+02:00
# 1                         E19        0.000  2025-03-30T11:46:56+02:00
# 2                         E19        0.000  2025-03-30T11:46:56+02:00
# 3                         E19        0.000  2025-03-30T11:46:56+02:00
# 4                         E19        0.000  2025-03-30T11:46:56+02:00
# ...                       ...          ...                        ...
# 9028103                   E19        0.040  2025-06-01T17:56:32+02:00
# 9028104                   E19        0.036  2025-06-01T17:56:32+02:00
# 9028105                   E19        0.058  2025-06-01T17:56:32+02:00
# 9028106                   E19        0.001  2025-06-01T17:56:32+02:00
# 9028107                   E19        0.000  2025-06-01T17:56:32+02:00
#
# [9028108 rows x 10 columns]

# %% [markdown]
# ## Test API Elhub - Capacité installée
# ### Vue d'ensemble
# Ce test explore un nouveau dataset de l'API Elhub concernant la capacité installée par type de point de mesure et par groupe au niveau municipal avec une granularité quotidienne.
# ### Analyse du dataset
# #### Paramètres du dataset
#
# Dataset : INSTALLED_CAPACITY_PER_METERING_POINT_TYPE_GROUP_MUNICIPALITY_DAILY
#
# Granularité : Quotidienne (DAILY)
#
# Scope : Municipalités
#
# Métriques : Capacité installée par type de point de mesure et par groupe
# #### Paramètres de la requête
# ##### Période testée
#
# Début : 2023-05-03T00:00:00+02:00 (3 mai 2023, 00h00)
#
# Fin : 2023-05-04T00:00:00+02:00 (4 mai 2023, 00h00)
#
# Durée : 1day
# ### Cas d'usage potentiels
# 1. Planification énergétique
#
# Analyser la capacité installée par région
#
# Planifier les investissements infrastructurels
#
# 2. Analyse de transition énergétique
#
# Suivre l'évolution de la capacité renouvelable
#
# Comparer les types de production

# %%
headers = {
    
}

response = requests.get('https://api.elhub.no/energy-data/v0/municipalities?dataset=INSTALLED_CAPACITY_PER_METERING_POINT_TYPE_GROUP_MUNICIPALITY_DAILY&startDate=2023-05-03T00:00:00%2B02:00&endDate=2023-05-04T00:00:00%2B02:00', headers=headers)
if response.status_code == 200:
    print(response.json())
else:
    print('Error:', response.status_code)
# Out:
# {'meta': {'created': '2025-06-02T14:03:57+02:00', 'lastUpdated': '2025-06-02T08:28:23+02:00'}, 'links': {'self': 'https://api.elhub.no/energy-data/v0/municipalities?dataset=INSTALLED_CAPACITY_PER_METERING_POINT_TYPE_GROUP_MUNICIPALITY_DAILY&endDate=2023-05-04T00%3A00%3A00%2B02%3A00&startDate=2023-05-03T20%3A00%3A00%2B02%3A00'}, 'data': [{'type': 'municipality', 'id': '4032', 'attributes': {'municipalityNumber': '4032', 'name': 'Fyresdal', 'nameNo': 'Fyresdal', 'installedCapacityPerMeteringPointTypeGroupMunicipalityDaily': [{'usageDateId': 20230503, 'municipalityId': '4032', 'meteringPointTypeCode': 'E19', 'productionGroup': 'solar', 'installedCapacity': 213.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}, {'usageDateId': 20230503, 'municipalityId': '4032', 'meteringPointTypeCode': 'E18', 'productionGroup': 'hydro', 'installedCapacity': 132303.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}]}}, {'type': 'municipality', 'id': '1822', 'attributes': {'municipalityNumber': '1822', 'name': 'Leirfjord', 'nameNo': 'Leirfjord', 'installedCapacityPerMeteringPointTypeGroupMunicipalityDaily': [{'usageDateId': 20230503, 'municipalityId': '1822', 'meteringPointTypeCode': 'E19', 'productionGroup': 'solar', 'installedCapacity': 40.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}, {'usageDateId': 20230503, 'municipalityId': '1822', 'meteringPointTypeCode': 'E18', 'productionGroup': 'hydro', 'installedCapacity': 26200.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}]}}, {'type': 'municipality', 'id': '1824', 'attributes': {'municipalityNumber': '1824', 'name': 'Vefsn', 'nameNo': 'Vefsn', 'installedCapacityPerMeteringPointTypeGroupMunicipalityDaily': [{'usageDateId': 20230503, 'municipalityId': '1824', 'meteringPointTypeCode': 'E19', 'productionGroup': 'solar', 'installedCapacity': 75.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}, {'usageDateId': 20230503, 'municipalityId': '1824', 'meteringPointTypeCode': 'E18', 'productionGroup': 'hydro', 'installedCapacity': 20500.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}, {'usageDateId': 20230503, 'municipalityId': '1824', 'meteringPointTypeCode': 'E18', 'productionGroup': 'wind', 'installedCapacity': 400000.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}, {'usageDateId': 20230503, 'municipalityId': '1824', 'meteringPointTypeCode': 'E19', 'productionGroup': 'hydro', 'installedCapacity': 90.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}]}}, {'type': 'municipality', 'id': '1836', 'attributes': {'municipalityNumber': '1836', 'name': 'Rødøy', 'nameNo': 'Rødøy', 'installedCapacityPerMeteringPointTypeGroupMunicipalityDaily': [{'usageDateId': 20230503, 'municipalityId': '1836', 'meteringPointTypeCode': 'E19', 'productionGroup': 'solar', 'installedCapacity': 12.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}, {'usageDateId': 20230503, 'municipalityId': '1836', 'meteringPointTypeCode': 'E18', 'productionGroup': 'hydro', 'installedCapacity': 93671.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}]}}, {'type': 'municipality', 'id': '1834', 'attributes': {'municipalityNumber': '1834', 'name': 'Lurøy', 'nameNo': 'Lurøy', 'installedCapacityPerMeteringPointTypeGroupMunicipalityDaily': [{'usageDateId': 20230503, 'municipalityId': '1834', 'meteringPointTypeCode': 'E19', 'productionGroup': 'hydro', 'installedCapacity': 23.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}, {'usageDateId': 20230503, 'municipalityId': '1834', 'meteringPointTypeCode': 'E19', 'productionGroup': 'solar', 'installedCapacity': 108.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}, {'usageDateId': 20230503, 'municipalityId': '1834', 'meteringPointTypeCode': 'E18', 'productionGroup': 'hydro', 'installedCapacity': 400.0, 'lastUpdatedTime': '2025-06-02T08:28:23+02:00'}]}}, {'type': 'municipality', 'id': '3116', 'attributes': {'municipalityNumber': '3116', 'name': 'Skiptvet', 'nameNo': 'Skiptvet', 'installedCapacityPerMeteringPointTypeGroupMunicipalityDaily': [{'usageDateId': 20230503, 'municipalityId': '3116', 'meteri ...

# %%
# Constants
dataset = "INSTALLED_CAPACITY_PER_METERING_POINT_TYPE_GROUP_MUNICIPALITY_DAILY"  # Dataset identifier in the API
base_url = "https://api.elhub.no/energy-data/v0/municipalities"   # Base URL for the API endpoint

# Start and end dates
start_date = datetime(2025, 7, 15) # Start date for data collection authorized by the API
end_limit = datetime.now()

# Output CSV file
file_name = "municipalities_installed_capacity.csv"  

# Collections pour stocker toutes les données et détecter les colonnes
all_rows = []
all_fieldnames = set()

# Boucle principale pour traiter chaque jour
current_date = start_date
while current_date < end_limit:
    # Define the date window (1 day per request)
    end_date = current_date + timedelta(days=1)
    
    # Format dates as ISO 8601 (YYYY-MM-DD)
    start_str = current_date.strftime("%Y-%m-%d")
    end_str = end_date.strftime("%Y-%m-%d")
    
    # Construct the API URL
    url = (
        f"{base_url}?dataset={dataset}"
        f"&startDate={start_str}"
        f"&endDate={end_str}"
    )
    
    print(f"API call: {start_str} → {end_str}")
    
    try:
        response = requests.get(url)
        
        # Check HTTP response
        if response.status_code == 200:
            json_full = response.json()
            data = json_full.get("data", [])
            
            # Loop over each municipality record
            for item in data:
                if not isinstance(item, dict):
                    continue
                
                # Structure de base avec les champs de niveau supérieur
                base_row = {
                    "type": item.get("type"),
                    "id": item.get("id")
                }
                
                attr = item.get("attributes", {})
                
                # Ajouter automatiquement tous les attributs (sauf les données imbriquées)
                for attr_key, attr_value in attr.items():
                    if attr_key != "installedCapacityPerMeteringPointTypeGroupMunicipalityDaily":
                        base_row[attr_key] = attr_value
                
                # Loop over each installed capacity daily record
                for record in attr.get("installedCapacityPerMeteringPointTypeGroupMunicipalityDaily", []):
                    # Créer une ligne complète en combinant les infos de base et les données quotidiennes
                    row = {**base_row}  # Copier les données de base
                    
                    # Ajouter automatiquement toutes les données du record
                    for record_key, record_value in record.items():
                        row[record_key] = record_value
                    
                    # Ajouter toutes les clés trouvées à notre ensemble d'en-têtes
                    all_fieldnames.update(row.keys())
                    all_rows.append(row)
            
            if data:
                print(f"  {len(data)} municipality records processed for {start_str}")
            else:
                print(f"  No data available for {start_str}")
                
        else:
            print(f"API call failed: HTTP {response.status_code}")
            print(f"Response: {response.text}")
            
    except Exception as e:
        print(f"API error: {e}")
    
    # Move to the next day
    current_date = end_date
    time.sleep(1)  # Avoid rate limiting

# Écrire toutes les données dans le fichier CSV avec les en-têtes détectées automatiquement
if all_rows:
    with open(file_name, mode="w", newline="", encoding="utf-8") as file:
        # Trier les en-têtes pour avoir un ordre cohérent
        sorted_fieldnames = sorted(all_fieldnames)
        writer = csv.DictWriter(file, fieldnames=sorted_fieldnames)
        writer.writeheader()
        writer.writerows(all_rows)
    
    print(f"\nData saved in CSV file: {file_name}")
    print(f"Automatically detected columns: {sorted_fieldnames}")
    print(f"Total rows written: {len(all_rows)}")
    
    # Afficher quelques statistiques utiles
    if all_rows:
        print(f"\nSample of detected fields:")
        sample_row = all_rows[0]
        for key, value in sample_row.items():
            print(f"  {key}: {value} ({type(value).__name__})")
else:
    print("No data found in the specified date range")
# Out:
# API call: 2025-07-15 → 2025-07-16
#   343 municipality records processed for 2025-07-15
# API call: 2025-07-16 → 2025-07-17
#   343 municipality records processed for 2025-07-16
# API call: 2025-07-17 → 2025-07-18
#   343 municipality records processed for 2025-07-17
# API call: 2025-07-18 → 2025-07-19
#   343 municipality records processed for 2025-07-18
#
# Data saved in CSV file: municipalities_installed_capacity.csv
# Automatically detected columns: ['id', 'installedCapacity', 'lastUpdatedTime', 'meteringPointTypeCode', 'municipalityId', 'municipalityNumber', 'name', 'nameNo', 'productionGroup', 'type', 'usageDateId']
# Total rows written: 3596
#
# Sample of detected fields:
#   type: municipality (str)
#   id: 3428 (str)
#   municipalityNumber: 3428 (str)
#   name: Alvdal (str)
#   nameNo: Alvdal (str)
#   usageDateId: 20250715 (int)
#   municipalityId: 3428 (str)
#   meteringPointTypeCode: E19 (str)
#   productionGroup: solar (str)
#   installedCapacity: 1309.0 (float)
#   lastUpdatedTime: 2025-07-18T08:28:43+02:00 (str)

# %%
# Constants
dataset = "INSTALLED_CAPACITY_PER_METERING_POINT_TYPE_GROUP_MUNICIPALITY_DAILY"  # Dataset identifier in the API
base_url = "https://api.elhub.no/energy-data/v0/municipalities"   # Base URL for the API endpoint

# Start and end dates
start_date = datetime(2025, 7, 15) # Start date for data collection authorized by the API
end_limit = datetime.now()

# Output CSV file
file_name = "municipalities_installed_capacity.csv"  

# Collections pour stocker toutes les données et détecter les colonnes
all_rows = []
all_fieldnames = set()

# Boucle principale pour traiter chaque jour
current_date = start_date
while current_date < end_limit:
    # Define the date window (1 day per request)
    end_date = current_date + timedelta(days=1)
    
    # Format dates as ISO 8601 (YYYY-MM-DD)
    start_str = current_date.strftime("%Y-%m-%d")
    end_str = end_date.strftime("%Y-%m-%d")
    
    # Construct the API URL
    url = (
        f"{base_url}?dataset={dataset}"
        f"&startDate={start_str}"
        f"&endDate={end_str}"
    )
    
    print(f"API call: {start_str} → {end_str}")
    
    try:
        response = requests.get(url)
        
        # Check HTTP response
        if response.status_code == 200:
            json_full = response.json()
            data = json_full.get("data", [])
            
            # Loop over each municipality record
            for item in data:
                if not isinstance(item, dict):
                    continue
                
                # Structure de base avec les champs de niveau supérieur
                base_row = {
                    "type": item.get("type"),
                    "id": item.get("id")
                }
                
                attr = item.get("attributes", {})
                
                # Ajouter automatiquement tous les attributs (sauf les données imbriquées)
                for attr_key, attr_value in attr.items():
                    if attr_key != "installedCapacityPerMeteringPointTypeGroupMunicipalityDaily":
                        base_row[attr_key] = attr_value
                
                # Loop over each installed capacity daily record
                for record in attr.get("installedCapacityPerMeteringPointTypeGroupMunicipalityDaily", []):
                    # Créer une ligne complète en combinant les infos de base et les données quotidiennes
                    row = {**base_row}  # Copier les données de base
                    
                    # Ajouter automatiquement toutes les données du record
                    for record_key, record_value in record.items():
                        row[record_key] = record_value
                    
                    # Ajouter toutes les clés trouvées à notre ensemble d'en-têtes
                    all_fieldnames.update(row.keys())
                    all_rows.append(row)
            
            if data:
                print(f"  {len(data)} municipality records processed for {start_str}")
            else:
                print(f"  No data available for {start_str}")
                
        else:
            print(f"API call failed: HTTP {response.status_code}")
            print(f"Response: {response.text}")
            
    except Exception as e:
        print(f"API error: {e}")
    
    # Move to the next day
    current_date = end_date
    time.sleep(1)  # Avoid rate limiting

# Écrire toutes les données dans le fichier CSV avec les en-têtes détectées automatiquement
if all_rows:
    with open(file_name, mode="w", newline="", encoding="utf-8") as file:
        # Trier les en-têtes pour avoir un ordre cohérent
        sorted_fieldnames = sorted(all_fieldnames)
        writer = csv.DictWriter(file, fieldnames=sorted_fieldnames)
        writer.writeheader()
        writer.writerows(all_rows)
    
    print(f"\nData saved in CSV file: {file_name}")
    print(f"Automatically detected columns: {sorted_fieldnames}")
    print(f"Total rows written: {len(all_rows)}")
    
    # Afficher quelques statistiques utiles
    if all_rows:
        print(f"\nSample of detected fields:")
        sample_row = all_rows[0]
        for key, value in sample_row.items():
            print(f"  {key}: {value} ({type(value).__name__})")
else:
    print("No data found in the specified date range")
# Out:
# API call: 2021-01-01 → 2021-01-02
#   701 records written for 2021-01-01
# API call: 2021-01-02 → 2021-01-03
#   701 records written for 2021-01-02
# API call: 2021-01-03 → 2021-01-04
#   701 records written for 2021-01-03
# API call: 2021-01-04 → 2021-01-05
#   701 records written for 2021-01-04
# API call: 2021-01-05 → 2021-01-06
#   701 records written for 2021-01-05
# API call: 2021-01-06 → 2021-01-07
#   701 records written for 2021-01-06
# API call: 2021-01-07 → 2021-01-08
#   701 records written for 2021-01-07
# API call: 2021-01-08 → 2021-01-09
#   701 records written for 2021-01-08
# API call: 2021-01-09 → 2021-01-10
#   701 records written for 2021-01-09
# API call: 2021-01-10 → 2021-01-11
#   701 records written for 2021-01-10
# API call: 2021-01-11 → 2021-01-12
#   702 records written for 2021-01-11
# API call: 2021-01-12 → 2021-01-13
#   702 records written for 2021-01-12
# API call: 2021-01-13 → 2021-01-14
#   702 records written for 2021-01-13
# API call: 2021-01-14 → 2021-01-15
#   702 records written for 2021-01-14
# API call: 2021-01-15 → 2021-01-16
#   702 records written for 2021-01-15
# API call: 2021-01-16 → 2021-01-17
#   702 records written for 2021-01-16
# API call: 2021-01-17 → 2021-01-18
#   702 records written for 2021-01-17
# API call: 2021-01-18 → 2021-01-19
#   702 records written for 2021-01-18
# API call: 2021-01-19 → 2021-01-20
#   702 records written for 2021-01-19
# API call: 2021-01-20 → 2021-01-21
#   702 records written for 2021-01-20
# API call: 2021-01-21 → 2021-01-22
#   702 records written for 2021-01-21
# API call: 2021-01-22 → 2021-01-23
#   702 records written for 2021-01-22
# API call: 2021-01-23 → 2021-01-24
#   702 records written for 2021-01-23
# API call: 2021-01-24 → 2021-01-25
#   702 records written for 2021-01-24
# API call: 2021-01-25 → 2021-01-26
#   702 records written for 2021-01-25
# API call: 2021-01-26 → 2021-01-27
#   702 records written for 2021-01-26
# API call: 2021-01-27 → 2021-01-28
#   702 records written for 2021-01-27
# API call: 2021-01-28 → 2021-01-29
#   702 records written for 2021-01-28
# API call: 2021-01-29 → 2021-01-30
#   702 records written for 2021-01-29
# API call: 2021-01-30 → 2021-01-31
#   702 records written for 2021-01-30
# API call: 2021-01-31 → 2021-02-01
#   702 records written for 2021-01-31
# API call: 2021-02-01 → 2021-02-02
#   702 records written for 2021-02-01
# API call: 2021-02-02 → 2021-02-03
#   702 records written for 2021-02-02
# API call: 2021-02-03 → 2021-02-04
#   702 records written for 2021-02-03
# API call: 2021-02-04 → 2021-02-05
#   702 records written for 2021-02-04
# API call: 2021-02-05 → 2021-02-06
#   703 records written for 2021-02-05
# API call: 2021-02-06 → 2021-02-07
#   703 records written for 2021-02-06
# API call: 2021-02-07 → 2021-02-08
#   703 records written for 2021-02-07
# API call: 2021-02-08 → 2021-02-09
#   703 records written for 2021-02-08
# API call: 2021-02-09 → 2021-02-10
#   703 records written for 2021-02-09
# API call: 2021-02-10 → 2021-02-11
#   703 records written for 2021-02-10
# API call: 2021-02-11 → 2021-02-12
#   703 records written for 2021-02-11
# API call: 2021-02-12 → 2021-02-13
#   703 records written for 2021-02-12
# API call: 2021-02-13 → 2021-02-14
#   703 records written for 2021-02-13
# API call: 2021-02-14 → 2021-02-15
#   703 records written for 2021-02-14
# API call: 2021-02-15 → 2021-02-16
#   703 records written for 2021-02-15
# API call: 2021-02-16 → 2021-02-17
#   703 records written for 2021-02-16
# API call: 2021-02-17 → 2021-02-18
#   705 records written for 2021-02-17
# API call: 2021-02-18 → 2021-02-19
#   705 records written for 2021-02-18
# API call: 2021-02-19 → 2021-02-20
#   705 records written for 2021-02-19
# API call: 2021-02-20 → 2021-02-21
#   705 records written for 2021-02-20
# API call: 2021-02-21 → 2021-02-22
#   705 records written for 2021-02-21
# API call: 2021-02-22 → 2021-02-23
#   705 records written for 2021-02-22
# API call: 2021-02-23 → 2021-02-24
#   705 records written for 2021-02-23
# API call: 2021-02-24 → 2021-02-25
#   705 records written for 2021-02-24
# API call: 2021-02-25 → 2021-02-26
#   705 records written for 2021-02-25
# API call: 2021-02-26 → 2021-02-27
#   705 records written for 2021-02-26
# API call: 2021-02-27 → 2021-02-28
#   705 records written for 2021-02-27
# API call: 2021-02-28 → 2021-03-01
#   705 records written for 2021-02-28
# API call: 2021-03-01 → 2021-03-02
#   705 records written for 2021-03-01
# API call: 2021-03-02 → 2021-03-03
#   705 records written for 2021-03-02
# API call: 2021-03-03 → 2021-03-04
#   705 records written for 2021-03-03
# API call: 2021-03-04 → 2021-03-05
#   705 records written for 2021-03-04
# API call: 2021-03-05 → 2021-03-06
#   705 records written for 2021-03-05
# API call: 2021-03-06 → 2021-03-07
#   705 records written for 2021-03-06
# API call: 2021-03-07 → 2021-03-08
#   705 records written for 2021-03-07
# API call: 2021-03-08 → 2021-03-09
#   706 records written for 2021-03-08
# API call: 2021-03-09 → 2021-03-10
#   706 records written for 2021-03-09
# API call: 2021-03-10 → 2021-03-11
#   706 records written for 2021-03-10
# API call: 2021-03-11 → 2021-03-12
#   706 records written for 2021-03-11
# API call: 2021-03-12 → 2021-03-13
#   706 records written for 2021-03-12
# API call: 2021-03-13 → 2021-03-14
#   706 records written for 2021-03-13
# API call: 2021-03-14 → 2021-03-15
#   706 records written for 2021-03-14
# API call: 2021-03-15 → 2021-03-16
#   706 records written for 2021-03-15
# API call: 2021-03-16 → 2021-03-17
#   706 records written for 2021-03-16
# API call: 2021-03-17 → 2021-03-18
#   707 records written for 2021-03-17
# API call: 2021-03-18 → 2021-03-19
#   708 records written for 2021-03-18
# API call: 2021-03-19 → 2021-03-20
#   708 records written for 2021-03-19
# API call: 2021-03-20 → 2021-03-21
#   708 records written for 2021-03-20
# API call: 2021-03-21 → 2021-03-22
#   708 records written for 2021-03-21
# API call: 2021-03-22 → 2021-03-23
#   708 records written for 2021-03-22
# API call: 2021-03-23 → 2021-03-24
#   709 records written for 2021-03-23
# API call: 2021-03-24 → 2021-03-25
#   709 records written for 2021-03-24
# API call: 2021-03-25 → 2021-03-26
#   711 records written for 2021-03-25
# API call: 2021-03-26 → 2021-03-27
#   711 records written for 2021-03-26
# API call: 2021-03-27 → 2021-03-28
#   711 records written for 2021-03-27
# API call: 2021-03-28 → 2021-03-29
#   711 records written for 2021-03-28
# API call: 2021-03-29 → 2021-03-30
#   711 records written for 2021-03-29
# API call: 2021-03-30 → 2021-03-31
#   711 records written for 2021-03-30
# API call: 2021-03-31 → 2021-04-01
#   711 records written for 2021-03-31
# API call: 2021-04-01 → 2021-04-02
#   711 records written for 2021-04-01
# API call: 2021-04-02 → 2021-04-03
#   711 records written for 2021-04-02
# API call: 2021-04-03 → 2021-04-04
#   711 records written for 2021-04-03
# API call: 2021-04-04 → 2021-04-05
#   711 records written for 2021-04-04
# API call: 2021-04-05 → 2021-04-06
#   711 records written for 2021-04-05
# API call: 2021-04-06 → 2021-04-07
#   711 records written for 2021-04-06
# API call: 2021-04-07 → 2021-04-08
#   711 records written for 2021-04-07
# API call: 2021-04-08 → 2021-04-09
#   713 records written for 2021-04-08
# API call: 2021-04-09 → 2021-04-10
#   713 records written for 2021-04-09
# API call: 2021-04-10 → 2021-04-11
#   713 records written for 2021-04-10
# API call: 2021-04-11 → 2021-04-12
#   713 records written for 2021-04-11
# API call: 2021-04-12 → 2021-04-13
#   713 records written for 2021-04-12
# API call: 2021-04-13 → 2021-04-14
#   713 records written for 2021-04-13
# API call: 2021-04-14 → 2021-04-15
#   714 records written for 2021-04-14
# API call: 2021-04-15 → 2021-04-16
#   714 records written for 2021-04-15
# API call: 2021-04-16 → 2021-04-17
#   714 records written for 2021-04-16
# API call: 2021-04-17 → 2021-04-18
#   713 records written for 2021-04-17
# API call: 2021-04-18 → 2021-04-19
#   713 records written for 2021-04-18
# API call: 2021-04-19 → 2021-04-20
#   713 records written for 2021-04-19
# API call: 2021-04-20 → 2021-04-21
#   713 records written for 2021-04-20
# API call: 2021-04-21 → 2021-04-22
#   713 records written for 2021-04-21
# API call: 2021-04-22 → 2021-04-23
#   714 records written for 2021-04-22
# API call: 2021-04-23 → 2021-04-24
#   716 records written for 2021-04-23
# API call: 2021-04-24 → 2021-04-25
#   716 records written for 2021-04-24
# API call: 2021-04-25 → 2021-04-26
#   716 records written for 2021-04-25
# API call: 2021-04-26 → 2021-04-27
#   717 records written for 2021-04-26
# API call: 2021-04-27 → 2021-04-28
#   717 records written for 2021-04-27
# API call: 2021-04-28 → 2021-04-29
#   717 records written for 2021-04-28
# API call: 2021-04-29 → 2021-04-30
#   717 records written for 2021-04-29
# API call: 2021-04-30 → 2021-05-01
#  API error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# API call: 2021-05-01 → 2021-05-02
#  API error: HTTPSConnectionPool(host='api.elhub.no', port=443): Max retries exceeded with url: /energy-data/v0/municipalities?dataset=INSTALLED_CAPACITY_PER_METERING_POINT_TYPE_GROUP_MUNICIPALITY_DAILY&startDate=2021-05-01&endDate=2021-05-02 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001EEDE9C5AE0>: Failed to resolve 'api.elhub.no' ([Errno 11001] getaddrinfo failed)"))
# API call: 2021-05-02 → 2021-05-03
#  API error: HTTPSConnectionPool(host='api.elhub.no', port=443): Max retries exceeded with url: /energy-data/v0/municipalities?dataset=INSTALLED_CAPACITY_PER_METERING_POINT_TYPE_GROUP_MUNICIPALITY_DAILY&startDate=2021-05-02&endDate=2021-05-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001EEDEB71420>: Failed to resolve 'api.elhub.no' ([Errno 11001] getaddrinfo failed)"))
# API call: 2021-05-03 → 2021-05-04
#  API error: HTTPSConnectionPool(host='api.elhub.no', port=443): Max retries exceeded with url: /energy-data/v0/municipalities?dataset=INSTALLED_CAPACITY_PER_METERING_POINT_TYPE_GROUP_MUNICIPALITY_DAILY&startDate=2021-05-03&endDate=2021-05-04 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001EEDEB71600>: Failed to resolve 'api.elhub.no' ([Errno 11001] getaddrinfo failed)"))
# API call: 2021-05-04 → 2021-05-05
#  API error: HTTPSConnectionPool(host='api.elhub.no', port=443): Max retries exceeded with url: /energy-data/v0/municipalities?dataset=INSTALLED_CAPACITY_PER_METERING_POINT_TYPE_GROUP_MUNICIPALITY_DAILY&startDate=2021-05-04&endDate=2021-05-05 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000
#   764 records written for 2022-06-27
# API call: 2022-06-28 → 2022-06-29
#   764 records written for 2022-06-28
# API call: 2022-06-29 → 2022-06-30
#   764 records written for 2022-06-29
# API call: 2022-06-30 → 2022-07-01
#   764 records written for 2022-06-30
# API call: 2022-07-01 → 2022-07-02
#   765 records written for 2022-07-01
# API call: 2022-07-02 → 2022-07-03
#   765 records written for 2022-07-02
# API call: 2022-07-03 → 2022-07-04
#   765 records written for 2022-07-03
# ...
# API call: 2024-10-22 → 2024-10-23
#   864 records written for 2024-10-22
# API call: 2024-10-23 → 2024-10-24
#   864 records written for 2024-10-23
# API call: 2024-10-24 → 2024-10-25
#   864 records written for 2024-10-24
# API call: 2024-10-25 → 2024-10-26
#   864 records written for 2024-10-25
# API call: 2024-10-26 → 2024-10-27
#   864 records written for 2024-10-26
# API call: 2024-10-27 → 2024-10-28
#   864 records written for 2024-10-27
# API call: 2024-10-28 → 2024-10-29
#   865 records written for 2024-10-28
# API call: 2024-10-29 → 2024-10-30
#   866 records written for 2024-10-29
# API call: 2024-10-30 → 2024-10-31
#   866 records written for 2024-10-30
# API call: 2024-10-31 → 2024-11-01
#   866 records written for 2024-10-31
# API call: 2024-11-01 → 2024-11-02
#   868 records written for 2024-11-01
# API call: 2024-11-02 → 2024-11-03
#   868 records written for 2024-11-02
# API call: 2024-11-03 → 2024-11-04
#   868 records written for 2024-11-03
# API call: 2024-11-04 → 2024-11-05
#   868 records written for 2024-11-04
# API call: 2024-11-05 → 2024-11-06
#   868 records written for 2024-11-05
# API call: 2024-11-06 → 2024-11-07
#   868 records written for 2024-11-06
# API call: 2024-11-07 → 2024-11-08
#   868 records written for 2024-11-07
# API call: 2024-11-08 → 2024-11-09
#   868 records written for 2024-11-08
# API call: 2024-11-09 → 2024-11-10
#   868 records written for 2024-11-09
# API call: 2024-11-10 → 2024-11-11
#   868 records written for 2024-11-10
# API call: 2024-11-11 → 2024-11-12
#   868 records written for 2024-11-11
# API call: 2024-11-12 → 2024-11-13
#   868 records written for 2024-11-12
# API call: 2024-11-13 → 2024-11-14
#   868 records written for 2024-11-13
# API call: 2024-11-14 → 2024-11-15
#   869 records written for 2024-11-14
# API call: 2024-11-15 → 2024-11-16
#   869 records written for 2024-11-15
# API call: 2024-11-16 → 2024-11-17
#   869 records written for 2024-11-16
# API call: 2024-11-17 → 2024-11-18
#   869 records written for 2024-11-17
# API call: 2024-11-18 → 2024-11-19
#   869 records written for 2024-11-18
# API call: 2024-11-19 → 2024-11-20
#   869 records written for 2024-11-19
# API call: 2024-11-20 → 2024-11-21
#   869 records written for 2024-11-20
# API call: 2024-11-21 → 2024-11-22
#   869 records written for 2024-11-21
# API call: 2024-11-22 → 2024-11-23
#   868 records written for 2024-11-22
# API call: 2024-11-23 → 2024-11-24
#   868 records written for 2024-11-23
# API call: 2024-11-24 → 2024-11-25
#   868 records written for 2024-11-24
# API call: 2024-11-25 → 2024-11-26
#   869 records written for 2024-11-25
# API call: 2024-11-26 → 2024-11-27
#   869 records written for 2024-11-26
# API call: 2024-11-27 → 2024-11-28
# API call: 2025-01-09 → 2025-01-10
#   872 records written for 2025-01-09
# API call: 2025-01-10 → 2025-01-11
#   872 records written for 2025-01-10
# API call: 2025-01-11 → 2025-01-12
#   872 records written for 2025-01-11
# API call: 2025-01-12 → 2025-01-13
#   872 records written for 2025-01-12
# API call: 2025-01-13 → 2025-01-14
#   873 records written for 2025-01-13
# API call: 2025-01-14 → 2025-01-15
#   873 records written for 2025-01-14
# API call: 2025-01-15 → 2025-01-16
#   873 records written for 2025-01-15
# API call: 2025-01-16 → 2025-01-17
#   873 records written for 2025-01-16
# API call: 2025-01-17 → 2025-01-18
#   873 records written for 2025-01-17
# API call: 2025-01-18 → 2025-01-19
#   873 records written for 2025-01-18
# API call: 2025-01-19 → 2025-01-20
#   873 records written for 2025-01-19
# API call: 2025-01-20 → 2025-01-21
#   873 records written for 2025-01-20
# API call: 2025-01-21 → 2025-01-22
#   873 records written for 2025-01-21
# API call: 2025-01-22 → 2025-01-23
#   874 records written for 2025-01-22
# API call: 2025-01-23 → 2025-01-24
#   874 records written for 2025-01-23
# API call: 2025-01-24 → 2025-01-25
#   875 records written for 2025-01-24
# API call: 2025-01-25 → 2025-01-26
#   875 records written for 2025-01-25
# API call: 2025-01-26 → 2025-01-27
#   875 records written for 2025-01-26
# API call: 2025-01-27 → 2025-01-28
#   875 records written for 2025-01-27
# API call: 2025-01-28 → 2025-01-29
#   875 records written for 2025-01-28
# API call: 2025-01-29 → 2025-01-30
#   875 records written for 2025-01-29
# API call: 2025-01-30 → 2025-01-31
#   875 records written for 2025-01-30
# API call: 2025-01-31 → 2025-02-01
#   875 records written for 2025-01-31
# API call: 2025-02-01 → 2025-02-02
#   875 records written for 2025-02-01
# API call: 2025-02-02 → 2025-02-03
#   875 records written for 2025-02-02
# API call: 2025-02-03 → 2025-02-04
#   875 records written for 2025-02-03
# API call: 2025-02-04 → 2025-02-05
#   875 records written for 2025-02-04
# API call: 2025-02-05 → 2025-02-06
#   875 records written for 2025-02-05
# API call: 2025-02-06 → 2025-02-07
#   875 records written for 2025-02-06
# API call: 2025-02-07 → 2025-02-08
#   875 records written for 2025-02-07
# API call: 2025-02-08 → 2025-02-09
#   875 records written for 2025-02-08
# API call: 2025-02-09 → 2025-02-10
#   875 records written for 2025-02-09
# API call: 2025-02-10 → 2025-02-11
#   875 records written for 2025-02-10
# API call: 2025-02-11 → 2025-02-12
#   875 records written for 2025-02-11
# API call: 2025-02-12 → 2025-02-13
#   875 records written for 2025-02-12
# API call: 2025-02-13 → 2025-02-14
#   876 records written for 2025-02-13
# API call: 2025-02-14 → 2025-02-15
#   876 records written for 2025-02-14
# API call: 2025-02-15 → 2025-02-16
#   876 records written for 2025-02-15
# API call: 2025-02-16 → 2025-02-17
#   876 records written for 2025-02-16
# API call: 2025-02-17 → 2025-02-18
#   876 records written for 2025-02-17
# API call: 2025-02-18 → 2025-02-19
#   877 records written for 2025-02-18
# API call: 2025-02-19 → 2025-02-20
#   878 records written for 2025-02-19
# API call: 2025-02-20 → 2025-02-21
#   878 records written for 2025-02-20
#   892 records written for 2025-05-17
# API call: 2025-05-18 → 2025-05-19
#   892 records written for 2025-05-18
# API call: 2025-05-19 → 2025-05-20
#   893 records written for 2025-05-19
# API call: 2025-05-20 → 2025-05-21
#   893 records written for 2025-05-20
# API call: 2025-05-21 → 2025-05-22
#   894 records written for 2025-05-21
# API call: 2025-05-22 → 2025-05-23
#   894 records written for 2025-05-22
# API call: 2025-05-23 → 2025-05-24
#   895 records written for 2025-05-23
# API call: 2025-05-24 → 2025-05-25
#   891 records written for 2025-05-24
# API call: 2025-05-25 → 2025-05-26
#   891 records written for 2025-05-25
# API call: 2025-05-26 → 2025-05-27
#   891 records written for 2025-05-26
# API call: 2025-05-27 → 2025-05-28
#   891 records written for 2025-05-27
# API call: 2025-05-28 → 2025-05-29
#   891 records written for 2025-05-28
# API call: 2025-05-29 → 2025-05-30
#   891 records written for 2025-05-29
# API call: 2025-05-30 → 2025-05-31
#   891 records written for 2025-05-30
# API call: 2025-05-31 → 2025-06-01
#   891 records written for 2025-05-31
# API call: 2025-06-01 → 2025-06-02
#   891 records written for 2025-06-01
# API call: 2025-06-02 → 2025-06-03
#   891 records written for 2025-06-02
#
#  Data saved in CSV file: municipalities_installed_capacity.csv

# %%
df_capacity=pd.read_csv('municipalities_installed_capacity.csv')

# %%
df_capacity
# Out:
#                  type    id  municipalityNumber       name     nameNo  \
# 0        municipality  5632                5632  Båtsfjord  Båtsfjord
# 1        municipality  1563                1563    Sunndal    Sunndal
# 2        municipality  1563                1563    Sunndal    Sunndal
# 3        municipality  1836                1836      Rødøy      Rødøy
# 4        municipality  1836                1836      Rødøy      Rødøy
# ...               ...   ...                 ...        ...        ...
# 1271167  municipality  4212                4212  Vegårshei  Vegårshei
# 1271168  municipality  4633                4633      Fedje      Fedje
# 1271169  municipality  3234                3234     Lunner     Lunner
# 1271170  municipality  3454                3454       Vang       Vang
# 1271171  municipality  3454                3454       Vang       Vang
#
#          usageDateId  municipalityId meteringPointTypeCode productionGroup  \
# 0           20210101            5632                   E18            wind
# 1           20210101            1563                   E18           hydro
# 2           20210101            1563                   E19           solar
# 3           20210101            1836                   E18           hydro
# 4           20210101            1836                   E19           solar
# ...              ...             ...                   ...             ...
# 1271167     20250602            4212                   E19           solar
# 1271168     20250602            4633                   E19           solar
# 1271169     20250602            3234                   E19           solar
# 1271170     20250602            3454                   E19           solar
# 1271171     20250602            3454                   E18           hydro
#
#          installedCapacity            lastUpdatedTime
# 0                 120000.0  2025-06-02T08:28:23+02:00
# 1                 514585.0  2025-06-02T08:28:23+02:00
# 2                     15.0  2025-06-02T08:28:23+02:00
# 3                  93671.0  2025-06-02T08:28:23+02:00
# 4                     12.0  2025-06-02T08:28:23+02:00
# ...                    ...                        ...
# 1271167              267.0  2025-06-02T14:27:27+02:00
# 1271168               38.0  2025-06-02T14:27:27+02:00
# 1271169             1730.0  2025-06-02T14:27:27+02:00
# 1271170              549.0  2025-06-02T14:27:27+02:00
# 1271171            82000.0  2025-06-02T14:27:27+02:00
#
# [1271172 rows x 11 columns]
